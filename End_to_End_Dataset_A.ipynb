# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import torch
import numpy as np
from tqdm import tqdm

# Step 1: Load your train dataset without normalization
transform_no_norm = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

train_dataset_raw = datasets.ImageFolder('/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/train', transform=transform_no_norm)
train_loader = DataLoader(train_dataset_raw, batch_size=64, shuffle=False, num_workers=2)

# Step 2: Compute mean and std
def get_mean_std(loader):
    mean = 0.
    std = 0.
    total_images = 0
    for images, _ in tqdm(loader):
        batch_samples = images.size(0)  # batch size (number of images)
        images = images.view(batch_samples, images.size(1), -1)  # flatten H and W
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)
        total_images += batch_samples

    mean /= total_images
    std /= total_images
    return mean, std

mean, std = get_mean_std(train_loader)

print("Mean:", mean)
print("Std:", std)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████| 35/35 [00:15<00:00,  2.29it/s]
# Mean: tensor([0.5285, 0.3926, 0.3573])
# Std: tensor([0.2076, 0.1692, 0.1621])

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import time
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'resnet50'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ------------------- Model ------------------- #
def get_model(model_name):
    if model_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)
    elif model_name == 'efficientnet_b0':
        model = timm.create_model('efficientnet_b0', pretrained=True)
        model.classifier = torch.nn.Linear(model.classifier.in_features, NUM_CLASSES)
    elif model_name == 'inception_v3':
        model = models.inception_v3(pretrained=True)
        model.AuxLogits.fc = torch.nn.Linear(model.AuxLogits.fc.in_features, NUM_CLASSES)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)

    elif model_name == 'vit_b_16':
        model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", num_labels=NUM_CLASSES)

    else:
        raise ValueError("Model name not recognized")
    
    return model

# Load model
model = get_model(MODEL_NAME).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# ------------------- Training Function ------------------- #
# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/resnet50.pth')
evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:35<00:00,  1.95it/s]
# Epoch 1/20, Train Loss: 0.7527, Train Accuracy: 0.6688
# Validation Loss: 0.6402, Validation Accuracy: 0.7382
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 2/20, Train Loss: 0.4529, Train Accuracy: 0.8248
# Validation Loss: 0.5592, Validation Accuracy: 0.7673
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 3/20, Train Loss: 0.3425, Train Accuracy: 0.8763
# Validation Loss: 0.6909, Validation Accuracy: 0.7382
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 4/20, Train Loss: 0.2296, Train Accuracy: 0.9177
# Validation Loss: 0.6259, Validation Accuracy: 0.8036
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 5/20, Train Loss: 0.1745, Train Accuracy: 0.9349
# Validation Loss: 0.6299, Validation Accuracy: 0.7891
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 6/20, Train Loss: 0.1750, Train Accuracy: 0.9372
# Validation Loss: 0.5741, Validation Accuracy: 0.7964
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 7/20, Train Loss: 0.1425, Train Accuracy: 0.9495
# Validation Loss: 0.7397, Validation Accuracy: 0.7673
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 8/20, Train Loss: 0.1258, Train Accuracy: 0.9540
# Validation Loss: 0.6243, Validation Accuracy: 0.8000
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 9/20, Train Loss: 0.1230, Train Accuracy: 0.9591
# Validation Loss: 0.7000, Validation Accuracy: 0.8000
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.19it/s]
# Epoch 10/20, Train Loss: 0.1187, Train Accuracy: 0.9563
# Validation Loss: 1.0203, Validation Accuracy: 0.7709
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.19it/s]
# Epoch 11/20, Train Loss: 0.1081, Train Accuracy: 0.9595
# Validation Loss: 0.7966, Validation Accuracy: 0.8073
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 12/20, Train Loss: 0.1017, Train Accuracy: 0.9686
# Validation Loss: 0.6170, Validation Accuracy: 0.8182
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.19it/s]
# Epoch 13/20, Train Loss: 0.0827, Train Accuracy: 0.9718
# Validation Loss: 0.6343, Validation Accuracy: 0.8109
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.19it/s]
# Epoch 14/20, Train Loss: 0.0958, Train Accuracy: 0.9668
# Validation Loss: 0.7481, Validation Accuracy: 0.8109
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 15/20, Train Loss: 0.1017, Train Accuracy: 0.9650
# Validation Loss: 0.6970, Validation Accuracy: 0.8255
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 16/20, Train Loss: 0.0594, Train Accuracy: 0.9804
# Validation Loss: 0.6218, Validation Accuracy: 0.8218
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 17/20, Train Loss: 0.0666, Train Accuracy: 0.9773
# Validation Loss: 0.5770, Validation Accuracy: 0.8291
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.21it/s]
# Epoch 18/20, Train Loss: 0.0642, Train Accuracy: 0.9795
# Validation Loss: 0.7737, Validation Accuracy: 0.8109
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 19/20, Train Loss: 0.0534, Train Accuracy: 0.9818
# Validation Loss: 0.6830, Validation Accuracy: 0.8109
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.21it/s]
# Epoch 20/20, Train Loss: 0.0464, Train Accuracy: 0.9836
# Validation Loss: 0.8446, Validation Accuracy: 0.8109
#
# ✅ Total Training Time: 683.28 seconds (11.39 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.82      0.76      0.79       106
#      Psoriasis       0.82      0.82      0.82       107
# Tinea_Ringworm       0.75      0.83      0.79        64
#
#       accuracy                           0.80       277
#      macro avg       0.80      0.80      0.80       277
#   weighted avg       0.80      0.80      0.80       277
#
# Confusion Matrix:

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'efficientnet_b0'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ------------------- Model ------------------- #
def get_model(model_name):
    if model_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)
    elif model_name == 'efficientnet_b0':
        model = timm.create_model('efficientnet_b0', pretrained=True)
        model.classifier = torch.nn.Linear(model.classifier.in_features, NUM_CLASSES)
    elif model_name == 'inception_v3':
        model = models.inception_v3(pretrained=True)
        model.AuxLogits.fc = torch.nn.Linear(model.AuxLogits.fc.in_features, NUM_CLASSES)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)
    elif model_name == 'convnext_tiny':
        model = timm.create_model('convnext_tiny', pretrained=True, num_classes=NUM_CLASSES)
        
    elif model_name == 'vit_b_16':
        model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", num_labels=NUM_CLASSES)
    elif model_name == 'swin_tiny':
        model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True)
        model.head = torch.nn.Linear(model.head.in_features, NUM_CLASSES)
    else:
        raise ValueError("Model name not recognized")
    
    return model

# Load model
model = get_model(MODEL_NAME).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)


# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/efficientnet_b0.pth')
evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.82it/s]
# Epoch 1/20, Train Loss: 0.9653, Train Accuracy: 0.5414
# Validation Loss: 0.8756, Validation Accuracy: 0.6255
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.87it/s]
# Epoch 2/20, Train Loss: 0.6620, Train Accuracy: 0.7525
# Validation Loss: 0.6773, Validation Accuracy: 0.7236
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 3/20, Train Loss: 0.4190, Train Accuracy: 0.8562
# Validation Loss: 0.5589, Validation Accuracy: 0.7745
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 4/20, Train Loss: 0.2770, Train Accuracy: 0.9063
# Validation Loss: 0.5157, Validation Accuracy: 0.7855
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.81it/s]
# Epoch 5/20, Train Loss: 0.1703, Train Accuracy: 0.9449
# Validation Loss: 0.5335, Validation Accuracy: 0.8145
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.83it/s]
# Epoch 6/20, Train Loss: 0.1249, Train Accuracy: 0.9627
# Validation Loss: 0.5540, Validation Accuracy: 0.7964
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 7/20, Train Loss: 0.0979, Train Accuracy: 0.9750
# Validation Loss: 0.5443, Validation Accuracy: 0.7964
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:23<00:00,  2.88it/s]
# Epoch 8/20, Train Loss: 0.0798, Train Accuracy: 0.9777
# Validation Loss: 0.5788, Validation Accuracy: 0.7964
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 9/20, Train Loss: 0.0622, Train Accuracy: 0.9836
# Validation Loss: 0.6321, Validation Accuracy: 0.8145
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.87it/s]
# Epoch 10/20, Train Loss: 0.0599, Train Accuracy: 0.9823
# Validation Loss: 0.6243, Validation Accuracy: 0.8036
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 11/20, Train Loss: 0.0347, Train Accuracy: 0.9904
# Validation Loss: 0.5647, Validation Accuracy: 0.8255
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 12/20, Train Loss: 0.0374, Train Accuracy: 0.9891
# Validation Loss: 0.5860, Validation Accuracy: 0.8218
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.83it/s]
# Epoch 13/20, Train Loss: 0.0370, Train Accuracy: 0.9886
# Validation Loss: 0.6715, Validation Accuracy: 0.8000
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 14/20, Train Loss: 0.0268, Train Accuracy: 0.9927
# Validation Loss: 0.6531, Validation Accuracy: 0.8327
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.87it/s]
# Epoch 15/20, Train Loss: 0.0255, Train Accuracy: 0.9909
# Validation Loss: 0.6623, Validation Accuracy: 0.8145
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 16/20, Train Loss: 0.0360, Train Accuracy: 0.9891
# Validation Loss: 0.7378, Validation Accuracy: 0.8145
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 17/20, Train Loss: 0.0399, Train Accuracy: 0.9868
# Validation Loss: 0.7455, Validation Accuracy: 0.8109
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.83it/s]
# Epoch 18/20, Train Loss: 0.0384, Train Accuracy: 0.9891
# Validation Loss: 0.7614, Validation Accuracy: 0.8291
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 19/20, Train Loss: 0.0291, Train Accuracy: 0.9895
# Validation Loss: 0.7770, Validation Accuracy: 0.8036
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:23<00:00,  2.89it/s]
# Epoch 20/20, Train Loss: 0.0278, Train Accuracy: 0.9914
# Validation Loss: 0.7800, Validation Accuracy: 0.8218
#
# ✅ Total Training Time: 526.13 seconds (8.77 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.77      0.79      0.78       106
#      Psoriasis       0.79      0.76      0.77       107
# Tinea_Ringworm       0.82      0.83      0.82        64
#
#       accuracy                           0.79       277
#      macro avg       0.79      0.79      0.79       277
#   weighted avg       0.79      0.79      0.79       277
#
# Confusion Matrix:

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'inception_v3'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
if MODEL_NAME == 'inception_v3':
    image_size = 299
else:
    image_size = 224
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5439, 0.4471, 0.4324], [0.2387, 0.2132, 0.2141])
])
val_test_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.5439, 0.4471, 0.4324], [0.2387, 0.2132, 0.2141])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ------------------- Model ------------------- #
def get_model(model_name):
    if model_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)
    elif model_name == 'efficientnet_b0':
        model = timm.create_model('efficientnet_b0', pretrained=True)
        model.classifier = torch.nn.Linear(model.classifier.in_features, NUM_CLASSES)
    elif model_name == 'inception_v3':
        model = models.inception_v3(pretrained=True,aux_logits=True)
        model.AuxLogits.fc = torch.nn.Linear(model.AuxLogits.fc.in_features, NUM_CLASSES)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)

        
    elif model_name == 'vit_b_16':
        model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", num_labels=NUM_CLASSES)

    else:
        raise ValueError("Model name not recognized")
    
    return model

# Load model
model = get_model(MODEL_NAME).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)


# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            if isinstance(outputs, tuple):
                outputs = outputs[0]

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/inception_v3.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.85it/s]
# Epoch 1/20, Train Loss: 0.8604, Train Accuracy: 0.5928
# Validation Loss: 0.7938, Validation Accuracy: 0.6436
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.84it/s]
# Epoch 2/20, Train Loss: 0.4623, Train Accuracy: 0.8248
# Validation Loss: 0.6534, Validation Accuracy: 0.7309
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:36<00:00,  1.87it/s]
# Epoch 3/20, Train Loss: 0.2807, Train Accuracy: 0.8981
# Validation Loss: 0.6598, Validation Accuracy: 0.7527
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:36<00:00,  1.86it/s]
# Epoch 4/20, Train Loss: 0.2002, Train Accuracy: 0.9345
# Validation Loss: 0.6124, Validation Accuracy: 0.7600
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 5/20, Train Loss: 0.1728, Train Accuracy: 0.9386
# Validation Loss: 0.5223, Validation Accuracy: 0.8073
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:36<00:00,  1.87it/s]
# Epoch 6/20, Train Loss: 0.1020, Train Accuracy: 0.9718
# Validation Loss: 0.5988, Validation Accuracy: 0.8218
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 7/20, Train Loss: 0.1106, Train Accuracy: 0.9600
# Validation Loss: 0.5533, Validation Accuracy: 0.8182
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.85it/s]
# Epoch 8/20, Train Loss: 0.0853, Train Accuracy: 0.9695
# Validation Loss: 0.6114, Validation Accuracy: 0.8036
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 9/20, Train Loss: 0.0937, Train Accuracy: 0.9736
# Validation Loss: 0.5849, Validation Accuracy: 0.8073
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 10/20, Train Loss: 0.0810, Train Accuracy: 0.9713
# Validation Loss: 0.6256, Validation Accuracy: 0.8145
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 11/20, Train Loss: 0.0793, Train Accuracy: 0.9732
# Validation Loss: 0.7058, Validation Accuracy: 0.7709
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 12/20, Train Loss: 0.0642, Train Accuracy: 0.9777
# Validation Loss: 0.6514, Validation Accuracy: 0.8000
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.85it/s]
# Epoch 13/20, Train Loss: 0.0612, Train Accuracy: 0.9763
# Validation Loss: 0.7652, Validation Accuracy: 0.7709
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 14/20, Train Loss: 0.0717, Train Accuracy: 0.9754
# Validation Loss: 0.6216, Validation Accuracy: 0.8073
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 15/20, Train Loss: 0.0448, Train Accuracy: 0.9854
# Validation Loss: 0.6508, Validation Accuracy: 0.8218
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 16/20, Train Loss: 0.0493, Train Accuracy: 0.9823
# Validation Loss: 0.6374, Validation Accuracy: 0.8145
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 17/20, Train Loss: 0.0375, Train Accuracy: 0.9891
# Validation Loss: 0.7157, Validation Accuracy: 0.8327
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 18/20, Train Loss: 0.0303, Train Accuracy: 0.9891
# Validation Loss: 0.6508, Validation Accuracy: 0.8364
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 19/20, Train Loss: 0.0557, Train Accuracy: 0.9845
# Validation Loss: 0.6549, Validation Accuracy: 0.7964
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:37<00:00,  1.86it/s]
# Epoch 20/20, Train Loss: 0.0525, Train Accuracy: 0.9809
# Validation Loss: 0.7672, Validation Accuracy: 0.7964
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.80      0.74      0.76       106
#       Psorasis       0.76      0.80      0.78       107
# Tinea Ringworm       0.74      0.77      0.75        64
#
#       accuracy                           0.77       277
#      macro avg       0.77      0.77      0.77       277
#   weighted avg       0.77      0.77      0.77       277
#
# Confusion Matrix:

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'vit_b_16'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
if MODEL_NAME == 'inception_v3':
    image_size = 299
else:
    image_size = 224
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ------------------- Model ------------------- #
def get_model(model_name):
    if model_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)
    elif model_name == 'efficientnet_b0':
        model = timm.create_model('efficientnet_b0', pretrained=True)
        model.classifier = torch.nn.Linear(model.classifier.in_features, NUM_CLASSES)
    elif model_name == 'inception_v3':
        model = models.inception_v3(pretrained=True,aux_logits=True)
        model.AuxLogits.fc = torch.nn.Linear(model.AuxLogits.fc.in_features, NUM_CLASSES)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)
    elif model_name == 'convnext_tiny':
        model = timm.create_model('convnext_tiny', pretrained=True, num_classes=NUM_CLASSES)
        
    elif model_name == 'vit_b_16':
        model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", num_labels=NUM_CLASSES)
    elif model_name == 'swin_tiny':
        model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True)
        model.head = torch.nn.Linear(model.head.in_features, NUM_CLASSES)
    else:
        raise ValueError("Model name not recognized")
    
    return model

# Load model
model = get_model(MODEL_NAME).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)



# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            logits = outputs.logits  # <-- extract logits

            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(logits, 1)  # <-- use logits, not outputs
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                logits = outputs.logits  # <-- extract logits

                loss = criterion(logits, labels)

                # Track accuracy
                _, preds = torch.max(logits, 1)  # <-- use logits
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            logits = outputs.logits
            _, preds = torch.max(logits, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/vit_b_16.pth')
evaluate_model(trained_model, test_loader)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.10it/s]
# Epoch 1/20, Train Loss: 0.8697, Train Accuracy: 0.6083
# Validation Loss: 0.6824, Validation Accuracy: 0.6982
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 2/20, Train Loss: 0.5110, Train Accuracy: 0.8053
# Validation Loss: 0.6619, Validation Accuracy: 0.7164
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 3/20, Train Loss: 0.3397, Train Accuracy: 0.8844
# Validation Loss: 0.5075, Validation Accuracy: 0.8073
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 4/20, Train Loss: 0.2565, Train Accuracy: 0.9117
# Validation Loss: 0.5288, Validation Accuracy: 0.7964
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 5/20, Train Loss: 0.1777, Train Accuracy: 0.9431
# Validation Loss: 0.5169, Validation Accuracy: 0.7964
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 6/20, Train Loss: 0.1194, Train Accuracy: 0.9622
# Validation Loss: 0.6605, Validation Accuracy: 0.7709
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.10it/s]
# Epoch 7/20, Train Loss: 0.1336, Train Accuracy: 0.9522
# Validation Loss: 0.5152, Validation Accuracy: 0.8145
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:06<00:00,  1.04it/s]
# Epoch 8/20, Train Loss: 0.0962, Train Accuracy: 0.9727
# Validation Loss: 0.4937, Validation Accuracy: 0.8218
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 9/20, Train Loss: 0.0684, Train Accuracy: 0.9754
# Validation Loss: 0.6617, Validation Accuracy: 0.7855
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 10/20, Train Loss: 0.0789, Train Accuracy: 0.9732
# Validation Loss: 0.5853, Validation Accuracy: 0.8218
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 11/20, Train Loss: 0.0430, Train Accuracy: 0.9877
# Validation Loss: 0.7399, Validation Accuracy: 0.7855
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 12/20, Train Loss: 0.0542, Train Accuracy: 0.9841
# Validation Loss: 0.7286, Validation Accuracy: 0.7745
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 13/20, Train Loss: 0.0611, Train Accuracy: 0.9791
# Validation Loss: 0.5871, Validation Accuracy: 0.8182
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 14/20, Train Loss: 0.0486, Train Accuracy: 0.9832
# Validation Loss: 0.7189, Validation Accuracy: 0.7927
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 15/20, Train Loss: 0.0528, Train Accuracy: 0.9818
# Validation Loss: 0.8523, Validation Accuracy: 0.7745
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 16/20, Train Loss: 0.0426, Train Accuracy: 0.9859
# Validation Loss: 0.6451, Validation Accuracy: 0.8109
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 17/20, Train Loss: 0.0201, Train Accuracy: 0.9936
# Validation Loss: 0.7400, Validation Accuracy: 0.8036
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 18/20, Train Loss: 0.0518, Train Accuracy: 0.9841
# Validation Loss: 0.6549, Validation Accuracy: 0.8218
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.10it/s]
# Epoch 19/20, Train Loss: 0.0446, Train Accuracy: 0.9873
# Validation Loss: 0.6990, Validation Accuracy: 0.8218
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.10it/s]
# Epoch 20/20, Train Loss: 0.0375, Train Accuracy: 0.9886
# Validation Loss: 0.6648, Validation Accuracy: 0.8073
#
# ✅ Total Training Time: 1325.67 seconds (22.09 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.79      0.85      0.82       106
#      Psoriasis       0.81      0.83      0.82       107
# Tinea_Ringworm       0.89      0.73      0.80        64
#
#       accuracy                           0.82       277
#      macro avg       0.83      0.81      0.81       277
#   weighted avg       0.82      0.82      0.82       277
#
# Confusion Matrix:

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'convnext_tiny'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
if MODEL_NAME == 'inception_v3':
    image_size = 299
else:
    image_size = 224
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# ------------------- Model ------------------- #
def freeze_model_except_head(model):
    for param in model.parameters():
        param.requires_grad = False
    # Unfreeze head (classifier or fc depending on model)
    if hasattr(model, 'head'):
        for param in model.head.parameters():
            param.requires_grad = True
    elif hasattr(model, 'classifier'):
        for param in model.classifier.parameters():
            param.requires_grad = True
    elif hasattr(model, 'fc'):
        for param in model.fc.parameters():
            param.requires_grad = True
    elif hasattr(model, 'AuxLogits'):
        for param in model.AuxLogits.parameters():
            param.requires_grad = True

def get_model(model_name, freeze=False):
    if model_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)

    elif model_name == 'efficientnet_b0':
        model = timm.create_model('efficientnet_b0', pretrained=True)
        model.classifier = torch.nn.Linear(model.classifier.in_features, NUM_CLASSES)

    elif model_name == 'inception_v3':
        model = models.inception_v3(pretrained=True, aux_logits=True)
        model.AuxLogits.fc = torch.nn.Linear(model.AuxLogits.fc.in_features, NUM_CLASSES)
        model.fc = torch.nn.Linear(model.fc.in_features, NUM_CLASSES)

    elif model_name == 'vit_b_16':
        model = ViTForImageClassification.from_pretrained(
            "google/vit-base-patch16-224-in21k", num_labels=NUM_CLASSES
        )

    elif model_name == 'convnext_tiny':
        model = timm.create_model('convnext_tiny', pretrained=True, num_classes=NUM_CLASSES)

    elif model_name == 'swin_tiny':
        model = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True)
        model.head = torch.nn.Linear(model.head.in_features, NUM_CLASSES)

    elif model_name == 'deit_small':
        model = timm.create_model('deit_small_patch16_224', pretrained=True)
        model.head = torch.nn.Linear(model.head.in_features, NUM_CLASSES)

    else:
        raise ValueError("Model name not recognized")

    if freeze:
        freeze_model_except_head(model)

    return model



# Load model
model = get_model(MODEL_NAME, freeze=True).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)



# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            logits = outputs  # <-- extract logits

            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(logits, 1)  # <-- use logits, not outputs
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                logits = outputs # <-- extract logits

                loss = criterion(logits, labels)

                # Track accuracy
                _, preds = torch.max(logits, 1)  # <-- use logits
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            logits = outputs
            _, preds = torch.max(logits, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/convnext_tiny.pth')
evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.44it/s]
# Epoch 1/20, Train Loss: 1.1382, Train Accuracy: 0.3703
# Validation Loss: 1.0506, Validation Accuracy: 0.4218
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.41it/s]
# Epoch 2/20, Train Loss: 1.0249, Train Accuracy: 0.4823
# Validation Loss: 0.9818, Validation Accuracy: 0.4909
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.38it/s]
# Epoch 3/20, Train Loss: 0.9626, Train Accuracy: 0.5241
# Validation Loss: 0.9449, Validation Accuracy: 0.5491
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.32it/s]
# Epoch 4/20, Train Loss: 0.9240, Train Accuracy: 0.5664
# Validation Loss: 0.9057, Validation Accuracy: 0.5782
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.35it/s]
# Epoch 5/20, Train Loss: 0.9063, Train Accuracy: 0.5837
# Validation Loss: 0.8860, Validation Accuracy: 0.6036
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.33it/s]
# Epoch 6/20, Train Loss: 0.8635, Train Accuracy: 0.6165
# Validation Loss: 0.8672, Validation Accuracy: 0.6145
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.32it/s]
# Epoch 7/20, Train Loss: 0.8643, Train Accuracy: 0.6119
# Validation Loss: 0.8569, Validation Accuracy: 0.6400
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.32it/s]
# Epoch 8/20, Train Loss: 0.8479, Train Accuracy: 0.6206
# Validation Loss: 0.8470, Validation Accuracy: 0.6255
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.33it/s]
# Epoch 9/20, Train Loss: 0.8198, Train Accuracy: 0.6351
# Validation Loss: 0.8426, Validation Accuracy: 0.6400
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.34it/s]
# Epoch 10/20, Train Loss: 0.8230, Train Accuracy: 0.6388
# Validation Loss: 0.8222, Validation Accuracy: 0.6582
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.37it/s]
# Epoch 11/20, Train Loss: 0.8032, Train Accuracy: 0.6328
# Validation Loss: 0.8164, Validation Accuracy: 0.6655
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.40it/s]
# Epoch 12/20, Train Loss: 0.7837, Train Accuracy: 0.6538
# Validation Loss: 0.8163, Validation Accuracy: 0.6836
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.33it/s]
# Epoch 13/20, Train Loss: 0.7846, Train Accuracy: 0.6642
# Validation Loss: 0.8085, Validation Accuracy: 0.6764
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:19<00:00,  3.45it/s]
# Epoch 14/20, Train Loss: 0.7682, Train Accuracy: 0.6661
# Validation Loss: 0.8026, Validation Accuracy: 0.6691
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.34it/s]
# Epoch 15/20, Train Loss: 0.7724, Train Accuracy: 0.6679
# Validation Loss: 0.7994, Validation Accuracy: 0.7018
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.39it/s]
# Epoch 16/20, Train Loss: 0.7310, Train Accuracy: 0.6984
# Validation Loss: 0.7894, Validation Accuracy: 0.6909
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.30it/s]
# Epoch 17/20, Train Loss: 0.7493, Train Accuracy: 0.6802
# Validation Loss: 0.7896, Validation Accuracy: 0.6582
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.36it/s]
# Epoch 18/20, Train Loss: 0.7469, Train Accuracy: 0.6847
# Validation Loss: 0.7827, Validation Accuracy: 0.6727
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.38it/s]
# Epoch 19/20, Train Loss: 0.7511, Train Accuracy: 0.6724
# Validation Loss: 0.7806, Validation Accuracy: 0.6945
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:20<00:00,  3.31it/s]
# Epoch 20/20, Train Loss: 0.7251, Train Accuracy: 0.7020
# Validation Loss: 0.7806, Validation Accuracy: 0.6836
#
# ✅ Total Training Time: 460.98 seconds (7.68 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.65      0.63      0.64       106
#      Psoriasis       0.66      0.67      0.67       107
# Tinea_Ringworm       0.68      0.69      0.68        64
#
#       accuracy                           0.66       277
#      macro avg       0.66      0.66      0.66       277
#   weighted avg       0.66      0.66      0.66       277
#
# Confusion Matrix:

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
import time
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'convnext_tiny'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
if MODEL_NAME == 'inception_v3':
    image_size = 299
else:
    image_size = 224
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)




# Load model
model = timm.create_model("convnext_tiny", pretrained=True, num_classes=NUM_CLASSES)
model = model.to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)



# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct_preds += (preds == labels).sum().item()
            total_preds += labels.size(0)

        train_loss = total_loss / len(train_loader)
        train_acc = correct_preds / total_preds
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        print(f"Epoch {epoch+1} Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}")

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_loss_epoch = val_loss / len(val_loader)
        val_acc_epoch = val_correct / val_total
        val_losses.append(val_loss_epoch)
        val_accuracies.append(val_acc_epoch)

        print(f"Validation Loss: {val_loss_epoch:.4f}, Validation Accuracy: {val_acc_epoch:.4f}")

        if val_acc_epoch > best_acc:
            best_acc = val_acc_epoch
            best_model_wts = model.state_dict()

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            logits = outputs
            _, preds = torch.max(logits, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/convnext_tiny_f.pth')
evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:06<00:00,  1.04it/s]
# Epoch 1 Train Loss: 1.0170, Train Accuracy: 0.5109
# Validation Loss: 0.7175, Validation Accuracy: 0.7018
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:04<00:00,  1.07it/s]
# Epoch 2 Train Loss: 0.6225, Train Accuracy: 0.7416
# Validation Loss: 0.5937, Validation Accuracy: 0.7418
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.10it/s]
# Epoch 3 Train Loss: 0.4014, Train Accuracy: 0.8394
# Validation Loss: 0.8911, Validation Accuracy: 0.7200
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:03<00:00,  1.09it/s]
# Epoch 4 Train Loss: 0.2671, Train Accuracy: 0.9022
# Validation Loss: 0.6814, Validation Accuracy: 0.7891
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.10it/s]
# Epoch 5 Train Loss: 0.1977, Train Accuracy: 0.9254
# Validation Loss: 0.6748, Validation Accuracy: 0.8218
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.13it/s]
# Epoch 6 Train Loss: 0.1972, Train Accuracy: 0.9313
# Validation Loss: 0.6114, Validation Accuracy: 0.8073
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:00<00:00,  1.14it/s]
# Epoch 7 Train Loss: 0.1072, Train Accuracy: 0.9659
# Validation Loss: 0.8781, Validation Accuracy: 0.7491
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.11it/s]
# Epoch 8 Train Loss: 0.1064, Train Accuracy: 0.9636
# Validation Loss: 0.5968, Validation Accuracy: 0.8145
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.12it/s]
# Epoch 9 Train Loss: 0.0634, Train Accuracy: 0.9804
# Validation Loss: 0.9763, Validation Accuracy: 0.7855
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.13it/s]
# Epoch 10 Train Loss: 0.0743, Train Accuracy: 0.9709
# Validation Loss: 0.5780, Validation Accuracy: 0.8400
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 11 Train Loss: 0.0765, Train Accuracy: 0.9763
# Validation Loss: 0.6767, Validation Accuracy: 0.8145
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:00<00:00,  1.14it/s]
# Epoch 12 Train Loss: 0.0898, Train Accuracy: 0.9686
# Validation Loss: 0.7850, Validation Accuracy: 0.8364
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:00<00:00,  1.13it/s]
# Epoch 13 Train Loss: 0.0484, Train Accuracy: 0.9818
# Validation Loss: 0.6218, Validation Accuracy: 0.8727
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.12it/s]
# Epoch 14 Train Loss: 0.0428, Train Accuracy: 0.9827
# Validation Loss: 0.7787, Validation Accuracy: 0.7927
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:02<00:00,  1.11it/s]
# Epoch 15 Train Loss: 0.0642, Train Accuracy: 0.9813
# Validation Loss: 0.8094, Validation Accuracy: 0.8291
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:07<00:00,  1.03it/s]
# Epoch 16 Train Loss: 0.0204, Train Accuracy: 0.9941
# Validation Loss: 0.9432, Validation Accuracy: 0.8327
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.13it/s]
# Epoch 17 Train Loss: 0.0530, Train Accuracy: 0.9827
# Validation Loss: 0.5613, Validation Accuracy: 0.8255
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.12it/s]
# Epoch 18 Train Loss: 0.0497, Train Accuracy: 0.9836
# Validation Loss: 0.8087, Validation Accuracy: 0.7782
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.13it/s]
# Epoch 19 Train Loss: 0.0590, Train Accuracy: 0.9773
# Validation Loss: 0.7242, Validation Accuracy: 0.8364
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:01<00:00,  1.11it/s]
# Epoch 20 Train Loss: 0.0326, Train Accuracy: 0.9891
# Validation Loss: 0.9134, Validation Accuracy: 0.8218
#
# ✅ Total Training Time: 1327.70 seconds (22.13 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.85      0.78      0.81       106
#      Psoriasis       0.77      0.86      0.81       107
# Tinea_Ringworm       0.82      0.77      0.79        64
#
#       accuracy                           0.81       277
#      macro avg       0.81      0.80      0.81       277
#   weighted avg       0.81      0.81      0.81       277
#
# Confusion Matrix:

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'swin_tiny'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
if MODEL_NAME == 'inception_v3':
    image_size = 299
else:
    image_size = 224
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)




# Load model
model = timm.create_model("swin_tiny_patch4_window7_224", pretrained=True, num_classes=NUM_CLASSES)
model = model.to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)



# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(num_epochs):
        model.train()
        total_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for images, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct_preds += (preds == labels).sum().item()
            total_preds += labels.size(0)

        train_loss = total_loss / len(train_loader)
        train_acc = correct_preds / total_preds
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        print(f"Epoch {epoch+1} Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}")

        # Validation phase
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(DEVICE), labels.to(DEVICE)
                outputs = model(images)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)

        val_loss_epoch = val_loss / len(val_loader)
        val_acc_epoch = val_correct / val_total
        val_losses.append(val_loss_epoch)
        val_accuracies.append(val_acc_epoch)

        print(f"Validation Loss: {val_loss_epoch:.4f}, Validation Accuracy: {val_acc_epoch:.4f}")

        if val_acc_epoch > best_acc:
            best_acc = val_acc_epoch
            best_model_wts = model.state_dict()

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            logits = outputs
            _, preds = torch.max(logits, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/swin_tiny.pth')
evaluate_model(trained_model, test_loader)
# Out:
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:42<00:00,  1.64it/s]
# Epoch 1 Train Loss: 0.8510, Train Accuracy: 0.6046
# Validation Loss: 0.7927, Validation Accuracy: 0.6618
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:39<00:00,  1.74it/s]
# Epoch 2 Train Loss: 0.5307, Train Accuracy: 0.7866
# Validation Loss: 0.5666, Validation Accuracy: 0.8000
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:39<00:00,  1.76it/s]
# Epoch 3 Train Loss: 0.3719, Train Accuracy: 0.8558
# Validation Loss: 0.4725, Validation Accuracy: 0.8182
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:39<00:00,  1.76it/s]
# Epoch 4 Train Loss: 0.2173, Train Accuracy: 0.9258
# Validation Loss: 0.5228, Validation Accuracy: 0.8109
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 5 Train Loss: 0.2099, Train Accuracy: 0.9263
# Validation Loss: 0.5324, Validation Accuracy: 0.8036
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 6 Train Loss: 0.1451, Train Accuracy: 0.9495
# Validation Loss: 0.5691, Validation Accuracy: 0.8327
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 7 Train Loss: 0.1210, Train Accuracy: 0.9604
# Validation Loss: 0.5803, Validation Accuracy: 0.8109
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 8 Train Loss: 0.0974, Train Accuracy: 0.9654
# Validation Loss: 0.6064, Validation Accuracy: 0.8364
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 9 Train Loss: 0.0979, Train Accuracy: 0.9654
# Validation Loss: 0.5579, Validation Accuracy: 0.8473
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 10 Train Loss: 0.0711, Train Accuracy: 0.9745
# Validation Loss: 0.5922, Validation Accuracy: 0.8255
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 11 Train Loss: 0.0745, Train Accuracy: 0.9750
# Validation Loss: 0.6219, Validation Accuracy: 0.8255
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 12 Train Loss: 0.0688, Train Accuracy: 0.9786
# Validation Loss: 0.5011, Validation Accuracy: 0.8655
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:39<00:00,  1.77it/s]
# Epoch 13 Train Loss: 0.0369, Train Accuracy: 0.9886
# Validation Loss: 0.7069, Validation Accuracy: 0.8291
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 14 Train Loss: 0.0430, Train Accuracy: 0.9832
# Validation Loss: 0.7476, Validation Accuracy: 0.8218
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 15 Train Loss: 0.0400, Train Accuracy: 0.9873
# Validation Loss: 0.6035, Validation Accuracy: 0.8691
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:39<00:00,  1.76it/s]
# Epoch 16 Train Loss: 0.0477, Train Accuracy: 0.9841
# Validation Loss: 0.7257, Validation Accuracy: 0.8218
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 17 Train Loss: 0.0493, Train Accuracy: 0.9832
# Validation Loss: 0.8159, Validation Accuracy: 0.8291
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 18 Train Loss: 0.0792, Train Accuracy: 0.9727
# Validation Loss: 0.9326, Validation Accuracy: 0.8109
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.77it/s]
# Epoch 19 Train Loss: 0.0478, Train Accuracy: 0.9841
# Validation Loss: 0.6936, Validation Accuracy: 0.8145
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:38<00:00,  1.78it/s]
# Epoch 20 Train Loss: 0.0611, Train Accuracy: 0.9832
# Validation Loss: 0.6804, Validation Accuracy: 0.8436
#
# ✅ Total Training Time: 837.77 seconds (13.96 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.86      0.74      0.79       106
#      Psoriasis       0.74      0.89      0.81       107
# Tinea_Ringworm       0.88      0.80      0.84        64
#
#       accuracy                           0.81       277
#      macro avg       0.83      0.81      0.81       277
#   weighted avg       0.82      0.81      0.81       277
#
# Confusion Matrix:

# %%
#Modified Resnet50

# %%
import torch
import torch.nn as nn
from torchvision import models

class ModifiedResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(ModifiedResNet50, self).__init__()
        base_model = models.resnet50(pretrained=True)
        
        # Remove the original FC layer
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])  # Exclude avgpool & fc

        self.pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP
        self.classifier = nn.Sequential(
            nn.Flatten(),                           # Flatten after GAP
            nn.Linear(2048, 512),                   # FC layer
            nn.BatchNorm1d(512),                    # BatchNorm
            nn.LeakyReLU(0.1, inplace=True),        # LeakyReLU
            nn.Dropout(0.4),
            nn.Linear(512, num_classes)             # Final classification layer
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

# %%
# Load model
model = ModifiedResNet50(num_classes=3).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)



# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_resnet50.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 1/20, Train Loss: 0.7626, Train Accuracy: 0.6724
# Validation Loss: 0.7816, Validation Accuracy: 0.7055
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 2/20, Train Loss: 0.4836, Train Accuracy: 0.8107
# Validation Loss: 0.7570, Validation Accuracy: 0.6982
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 3/20, Train Loss: 0.2923, Train Accuracy: 0.8954
# Validation Loss: 0.8586, Validation Accuracy: 0.6982
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 4/20, Train Loss: 0.2754, Train Accuracy: 0.8999
# Validation Loss: 0.6287, Validation Accuracy: 0.7636
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 5/20, Train Loss: 0.2609, Train Accuracy: 0.9040
# Validation Loss: 0.5861, Validation Accuracy: 0.8145
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 6/20, Train Loss: 0.1946, Train Accuracy: 0.9299
# Validation Loss: 0.6316, Validation Accuracy: 0.7745
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 7/20, Train Loss: 0.1376, Train Accuracy: 0.9522
# Validation Loss: 0.5918, Validation Accuracy: 0.8109
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 8/20, Train Loss: 0.1231, Train Accuracy: 0.9531
# Validation Loss: 0.7191, Validation Accuracy: 0.7855
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.15it/s]
# Epoch 9/20, Train Loss: 0.1152, Train Accuracy: 0.9563
# Validation Loss: 0.6069, Validation Accuracy: 0.8145
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.19it/s]
# Epoch 10/20, Train Loss: 0.1295, Train Accuracy: 0.9577
# Validation Loss: 0.6232, Validation Accuracy: 0.7964
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.15it/s]
# Epoch 11/20, Train Loss: 0.1121, Train Accuracy: 0.9650
# Validation Loss: 0.6188, Validation Accuracy: 0.8036
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 12/20, Train Loss: 0.0781, Train Accuracy: 0.9763
# Validation Loss: 0.5756, Validation Accuracy: 0.8400
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 13/20, Train Loss: 0.0743, Train Accuracy: 0.9741
# Validation Loss: 0.7239, Validation Accuracy: 0.8145
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.13it/s]
# Epoch 14/20, Train Loss: 0.0849, Train Accuracy: 0.9668
# Validation Loss: 0.6958, Validation Accuracy: 0.7891
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.12it/s]
# Epoch 15/20, Train Loss: 0.1178, Train Accuracy: 0.9581
# Validation Loss: 0.6335, Validation Accuracy: 0.8073
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.13it/s]
# Epoch 16/20, Train Loss: 0.0948, Train Accuracy: 0.9682
# Validation Loss: 0.7409, Validation Accuracy: 0.7855
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.13it/s]
# Epoch 17/20, Train Loss: 0.1089, Train Accuracy: 0.9600
# Validation Loss: 0.9577, Validation Accuracy: 0.7527
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:33<00:00,  2.08it/s]
# Epoch 18/20, Train Loss: 0.1029, Train Accuracy: 0.9645
# Validation Loss: 0.7179, Validation Accuracy: 0.7927
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.14it/s]
# Epoch 19/20, Train Loss: 0.0691, Train Accuracy: 0.9718
# Validation Loss: 0.5772, Validation Accuracy: 0.8327
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.14it/s]
# Epoch 20/20, Train Loss: 0.0741, Train Accuracy: 0.9736
# Validation Loss: 0.5979, Validation Accuracy: 0.8327
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.85      0.75      0.79       106
#       Psorasis       0.79      0.83      0.81       107
# Tinea Ringworm       0.76      0.86      0.81        64
#
#       accuracy                           0.81       277
#      macro avg       0.80      0.81      0.81       277
#   weighted avg       0.81      0.81      0.80       277
#
# Confusion Matrix:

# %%
import torch
import torch.nn as nn
from torchvision import models

class ModifiedResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(ModifiedResNet50, self).__init__()
        base_model = models.resnet50(pretrained=True)
        
        # Remove the original FC layer
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])  # Exclude avgpool & fc

        self.pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP
        self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(2048, 512),
        nn.BatchNorm1d(512),
        nn.LeakyReLU(0.1),
        nn.Dropout(0.4),
        nn.Linear(512, 128),
        nn.BatchNorm1d(128),
        nn.LeakyReLU(0.1),
        nn.Dropout(0.3),
        nn.Linear(128, num_classes)  
)

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

# %%
# Load model
model = ModifiedResNet50(num_classes=3).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)



# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified1_resnet50.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.15it/s]
# Epoch 1/20, Train Loss: 0.8306, Train Accuracy: 0.6278
# Validation Loss: 0.7852, Validation Accuracy: 0.6582
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 2/20, Train Loss: 0.5246, Train Accuracy: 0.8030
# Validation Loss: 0.6320, Validation Accuracy: 0.7673
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 3/20, Train Loss: 0.3962, Train Accuracy: 0.8626
# Validation Loss: 0.6069, Validation Accuracy: 0.7600
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 4/20, Train Loss: 0.2708, Train Accuracy: 0.9126
# Validation Loss: 0.5861, Validation Accuracy: 0.7818
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 5/20, Train Loss: 0.2657, Train Accuracy: 0.9113
# Validation Loss: 0.6574, Validation Accuracy: 0.7818
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 6/20, Train Loss: 0.2422, Train Accuracy: 0.9190
# Validation Loss: 0.5281, Validation Accuracy: 0.8036
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 7/20, Train Loss: 0.1684, Train Accuracy: 0.9472
# Validation Loss: 0.5107, Validation Accuracy: 0.8291
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 8/20, Train Loss: 0.1629, Train Accuracy: 0.9445
# Validation Loss: 0.5985, Validation Accuracy: 0.8073
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.14it/s]
# Epoch 9/20, Train Loss: 0.1556, Train Accuracy: 0.9490
# Validation Loss: 0.5070, Validation Accuracy: 0.8255
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 10/20, Train Loss: 0.1385, Train Accuracy: 0.9604
# Validation Loss: 0.5802, Validation Accuracy: 0.7818
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 11/20, Train Loss: 0.1259, Train Accuracy: 0.9581
# Validation Loss: 0.4949, Validation Accuracy: 0.8109
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 12/20, Train Loss: 0.1202, Train Accuracy: 0.9622
# Validation Loss: 0.6608, Validation Accuracy: 0.7709
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 13/20, Train Loss: 0.1374, Train Accuracy: 0.9581
# Validation Loss: 0.5424, Validation Accuracy: 0.8291
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 14/20, Train Loss: 0.1192, Train Accuracy: 0.9591
# Validation Loss: 0.5192, Validation Accuracy: 0.8291
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 15/20, Train Loss: 0.1097, Train Accuracy: 0.9682
# Validation Loss: 0.5455, Validation Accuracy: 0.7855
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 16/20, Train Loss: 0.0992, Train Accuracy: 0.9709
# Validation Loss: 0.5857, Validation Accuracy: 0.8145
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.13it/s]
# Epoch 17/20, Train Loss: 0.1091, Train Accuracy: 0.9663
# Validation Loss: 0.5604, Validation Accuracy: 0.8145
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.15it/s]
# Epoch 18/20, Train Loss: 0.0956, Train Accuracy: 0.9691
# Validation Loss: 0.5393, Validation Accuracy: 0.8145
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 19/20, Train Loss: 0.0692, Train Accuracy: 0.9786
# Validation Loss: 0.6225, Validation Accuracy: 0.8000
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 20/20, Train Loss: 0.0969, Train Accuracy: 0.9691
# Validation Loss: 0.6418, Validation Accuracy: 0.7927
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.80      0.75      0.77       106
#       Psorasis       0.70      0.82      0.76       107
# Tinea Ringworm       0.85      0.69      0.76        64
#
#       accuracy                           0.76       277
#      macro avg       0.78      0.75      0.76       277
#   weighted avg       0.77      0.76      0.76       277
#
# Confusion Matrix:

# %%
import torch
import torch.nn as nn
from torchvision import models

class ModifiedResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(ModifiedResNet50, self).__init__()
        base_model = models.resnet50(pretrained=True)
        
        # Remove the original FC layer
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])  # Exclude avgpool & fc

        self.pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP
        self.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(2048, 512),
        nn.BatchNorm1d(512),
        nn.SiLU(),                  # Replaces LeakyReLU
        nn.Dropout(0.4),
        nn.Linear(512, 128),
        nn.BatchNorm1d(128),
        nn.SiLU(),                  # Replaces LeakyReLU
        nn.Dropout(0.3),
        nn.Linear(128, num_classes) 
)

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

# %%
# Load model
model = ModifiedResNet50(num_classes=3).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)

# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        scheduler.step(val_epoch_loss)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, scheduler, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# ------------------- Save and Evaluate ------------------- #
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified2_resnet50.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/pragya/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 1/20, Train Loss: 0.8859, Train Accuracy: 0.6256
# Validation Loss: 0.8029, Validation Accuracy: 0.6873
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 2/20, Train Loss: 0.6580, Train Accuracy: 0.7957
# Validation Loss: 0.7150, Validation Accuracy: 0.7600
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 3/20, Train Loss: 0.5457, Train Accuracy: 0.8758
# Validation Loss: 0.6890, Validation Accuracy: 0.7673
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 4/20, Train Loss: 0.4642, Train Accuracy: 0.9231
# Validation Loss: 0.6618, Validation Accuracy: 0.7709
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 5/20, Train Loss: 0.4476, Train Accuracy: 0.9254
# Validation Loss: 0.7036, Validation Accuracy: 0.7855
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 6/20, Train Loss: 0.4290, Train Accuracy: 0.9327
# Validation Loss: 0.6458, Validation Accuracy: 0.8036
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 7/20, Train Loss: 0.3966, Train Accuracy: 0.9559
# Validation Loss: 0.6073, Validation Accuracy: 0.8327
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 8/20, Train Loss: 0.3863, Train Accuracy: 0.9577
# Validation Loss: 0.6584, Validation Accuracy: 0.7818
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 9/20, Train Loss: 0.3707, Train Accuracy: 0.9713
# Validation Loss: 0.5896, Validation Accuracy: 0.8218
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 10/20, Train Loss: 0.3613, Train Accuracy: 0.9759
# Validation Loss: 0.6127, Validation Accuracy: 0.8327
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 11/20, Train Loss: 0.3631, Train Accuracy: 0.9709
# Validation Loss: 0.6238, Validation Accuracy: 0.8000
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:32<00:00,  2.15it/s]
# Epoch 12/20, Train Loss: 0.3663, Train Accuracy: 0.9727
# Validation Loss: 0.6621, Validation Accuracy: 0.8036
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.17it/s]
# Epoch 13/20, Train Loss: 0.3511, Train Accuracy: 0.9795
# Validation Loss: 0.6206, Validation Accuracy: 0.8291
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.19it/s]
# Epoch 14/20, Train Loss: 0.3455, Train Accuracy: 0.9827
# Validation Loss: 0.6150, Validation Accuracy: 0.8255
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 15/20, Train Loss: 0.3323, Train Accuracy: 0.9891
# Validation Loss: 0.6029, Validation Accuracy: 0.8145
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 16/20, Train Loss: 0.3175, Train Accuracy: 0.9991
# Validation Loss: 0.5875, Validation Accuracy: 0.8400
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 17/20, Train Loss: 0.3239, Train Accuracy: 0.9932
# Validation Loss: 0.5862, Validation Accuracy: 0.8327
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 18/20, Train Loss: 0.3184, Train Accuracy: 0.9945
# Validation Loss: 0.5676, Validation Accuracy: 0.8327
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.18it/s]
# Epoch 19/20, Train Loss: 0.3164, Train Accuracy: 0.9968
# Validation Loss: 0.5730, Validation Accuracy: 0.8436
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.16it/s]
# Epoch 20/20, Train Loss: 0.3190, Train Accuracy: 0.9932
# Validation Loss: 0.5842, Validation Accuracy: 0.8364
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.88      0.77      0.82       106
#       Psorasis       0.77      0.89      0.82       107
# Tinea Ringworm       0.87      0.81      0.84        64
#
#       accuracy                           0.83       277
#      macro avg       0.84      0.82      0.83       277
#   weighted avg       0.83      0.83      0.83       277
#
# Confusion Matrix:

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50

class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate=32, bn_size=4, drop_rate=0.2):
        super(DenseLayer, self).__init__()
        inter_channels = bn_size * growth_rate
        self.net = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, inter_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(inter_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(inter_channels, growth_rate, kernel_size=3, stride=1, padding=1, bias=False),
        )
        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = self.net(x)
        if self.drop_rate > 0:
            new_features = nn.functional.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)

class DenseBlock(nn.Module):
    def __init__(self, num_layers, in_channels, growth_rate=32):
        super(DenseBlock, self).__init__()
        layers = []
        for i in range(num_layers):
            layers.append(DenseLayer(in_channels + i * growth_rate, growth_rate))
        self.block = nn.Sequential(*layers)

    def forward(self, x):
        return self.block(x)

class TransitionLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(TransitionLayer, self).__init__()
        self.transition = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.AvgPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.transition(x)

class ModifiedResNet50(nn.Module):
    def __init__(self, num_classes):
        super(ModifiedResNet50, self).__init__()
        base_model = resnet50(weights=None)  # or weights='IMAGENET1K_V1' if using pretrained

        # Keep all layers up to layer3
        self.backbone = nn.Sequential(
            base_model.conv1,
            base_model.bn1,
            base_model.relu,
            base_model.maxpool,
            base_model.layer1,
            base_model.layer2,
            base_model.layer3,
        )

        # Replace layer4 with DenseBlock
        self.dense_block = nn.Sequential(
            DenseBlock(num_layers=4, in_channels=1024, growth_rate=32),
            TransitionLayer(1024 + 4 * 32, 1024)
        )

        # Global pooling
        self.pool = nn.AdaptiveAvgPool2d((1, 1))

        # Custom classifier head
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.backbone(x)
        x = self.dense_block(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

# %%
# Load model
model = ModifiedResNet50(num_classes=3).to(DEVICE)

# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)

# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        scheduler.step(val_epoch_loss)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, scheduler, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# ------------------- Save and Evaluate ------------------- #
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified3_resnet50.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.21it/s]
# Epoch 1/20, Train Loss: 1.1097, Train Accuracy: 0.4017
# Validation Loss: 1.0981, Validation Accuracy: 0.4109
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.24it/s]
# Epoch 2/20, Train Loss: 1.0801, Train Accuracy: 0.4472
# Validation Loss: 1.1351, Validation Accuracy: 0.4109
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.24it/s]
# Epoch 3/20, Train Loss: 1.0550, Train Accuracy: 0.4691
# Validation Loss: 1.0579, Validation Accuracy: 0.4364
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.23it/s]
# Epoch 4/20, Train Loss: 1.0533, Train Accuracy: 0.4854
# Validation Loss: 1.0940, Validation Accuracy: 0.4545
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 5/20, Train Loss: 1.0324, Train Accuracy: 0.4964
# Validation Loss: 1.0633, Validation Accuracy: 0.4473
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.21it/s]
# Epoch 6/20, Train Loss: 1.0025, Train Accuracy: 0.5355
# Validation Loss: 1.0424, Validation Accuracy: 0.4909
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.23it/s]
# Epoch 7/20, Train Loss: 1.0130, Train Accuracy: 0.5155
# Validation Loss: 1.0737, Validation Accuracy: 0.4691
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.23it/s]
# Epoch 8/20, Train Loss: 0.9992, Train Accuracy: 0.5300
# Validation Loss: 1.0868, Validation Accuracy: 0.5273
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.23it/s]
# Epoch 9/20, Train Loss: 0.9847, Train Accuracy: 0.5469
# Validation Loss: 1.0595, Validation Accuracy: 0.4764
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.24it/s]
# Epoch 10/20, Train Loss: 0.9749, Train Accuracy: 0.5532
# Validation Loss: 1.0556, Validation Accuracy: 0.4582
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.25it/s]
# Epoch 11/20, Train Loss: 0.9431, Train Accuracy: 0.5823
# Validation Loss: 0.9918, Validation Accuracy: 0.5491
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.23it/s]
# Epoch 12/20, Train Loss: 0.9223, Train Accuracy: 0.6010
# Validation Loss: 1.0064, Validation Accuracy: 0.5200
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.22it/s]
# Epoch 13/20, Train Loss: 0.9295, Train Accuracy: 0.5883
# Validation Loss: 1.0437, Validation Accuracy: 0.5527
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.24it/s]
# Epoch 14/20, Train Loss: 0.9123, Train Accuracy: 0.5946
# Validation Loss: 0.9878, Validation Accuracy: 0.5527
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.22it/s]
# Epoch 15/20, Train Loss: 0.9063, Train Accuracy: 0.6174
# Validation Loss: 1.0008, Validation Accuracy: 0.5382
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.20it/s]
# Epoch 16/20, Train Loss: 0.8895, Train Accuracy: 0.6369
# Validation Loss: 1.0061, Validation Accuracy: 0.5418
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.22it/s]
# Epoch 17/20, Train Loss: 0.9041, Train Accuracy: 0.6274
# Validation Loss: 1.0222, Validation Accuracy: 0.5455
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.23it/s]
# Epoch 18/20, Train Loss: 0.8988, Train Accuracy: 0.6247
# Validation Loss: 1.0272, Validation Accuracy: 0.5200
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:30<00:00,  2.24it/s]
# Epoch 19/20, Train Loss: 0.8581, Train Accuracy: 0.6510
# Validation Loss: 0.9678, Validation Accuracy: 0.5600
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:31<00:00,  2.22it/s]
# Epoch 20/20, Train Loss: 0.8335, Train Accuracy: 0.6761
# Validation Loss: 0.9759, Validation Accuracy: 0.5418
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.53      0.55      0.54       106
#       Psorasis       0.55      0.50      0.52       107
# Tinea Ringworm       0.49      0.53      0.51        64
#
#       accuracy                           0.53       277
#      macro avg       0.52      0.53      0.53       277
#   weighted avg       0.53      0.53      0.53       277
#
# Confusion Matrix:

# %%
#Modified EfficientnetB0

# %%
import torch.nn as nn
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights

class ModifiedEfficientNetB0(nn.Module):
    def __init__(self, num_classes=3, freeze_blocks=5):
        super(ModifiedEfficientNetB0, self).__init__()
        self.base_model = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)

        # Optionally freeze first N feature blocks
        for param in self.base_model.features[:freeze_blocks]:
            param.requires_grad = False

        in_features = self.base_model.classifier[1].in_features

        # Replace classifier
        self.base_model.classifier = nn.Sequential(
            nn.Dropout(p=0.4, inplace=True),
            nn.Linear(in_features, 512),
            nn.BatchNorm1d(512),
            nn.SiLU(inplace=True),
            nn.Dropout(p=0.3, inplace=True),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(inplace=True),
            nn.Dropout(p=0.2, inplace=True),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        return self.base_model(x)

# %%
model = ModifiedEfficientNetB0(num_classes=3)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(DEVICE) 
# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)

# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        scheduler.step(val_epoch_loss)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, scheduler, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# ------------------- Save and Evaluate ------------------- #
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_efficientnetb0.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.82it/s]
# Epoch 1/20, Train Loss: 1.0239, Train Accuracy: 0.4900
# Validation Loss: 0.8933, Validation Accuracy: 0.6109
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 2/20, Train Loss: 0.8423, Train Accuracy: 0.6679
# Validation Loss: 0.8302, Validation Accuracy: 0.6982
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 3/20, Train Loss: 0.7239, Train Accuracy: 0.7543
# Validation Loss: 0.7508, Validation Accuracy: 0.7236
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.83it/s]
# Epoch 4/20, Train Loss: 0.6222, Train Accuracy: 0.8221
# Validation Loss: 0.7155, Validation Accuracy: 0.7636
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 5/20, Train Loss: 0.5770, Train Accuracy: 0.8521
# Validation Loss: 0.7079, Validation Accuracy: 0.7709
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 6/20, Train Loss: 0.5237, Train Accuracy: 0.8899
# Validation Loss: 0.6953, Validation Accuracy: 0.7745
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.87it/s]
# Epoch 7/20, Train Loss: 0.4647, Train Accuracy: 0.9236
# Validation Loss: 0.7184, Validation Accuracy: 0.7564
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 8/20, Train Loss: 0.4564, Train Accuracy: 0.9295
# Validation Loss: 0.6948, Validation Accuracy: 0.7964
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 9/20, Train Loss: 0.4378, Train Accuracy: 0.9431
# Validation Loss: 0.6879, Validation Accuracy: 0.7855
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.68it/s]
# Epoch 10/20, Train Loss: 0.4155, Train Accuracy: 0.9595
# Validation Loss: 0.6814, Validation Accuracy: 0.7927
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.80it/s]
# Epoch 11/20, Train Loss: 0.3937, Train Accuracy: 0.9677
# Validation Loss: 0.6875, Validation Accuracy: 0.7782
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 12/20, Train Loss: 0.3932, Train Accuracy: 0.9668
# Validation Loss: 0.6823, Validation Accuracy: 0.7891
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 13/20, Train Loss: 0.3864, Train Accuracy: 0.9682
# Validation Loss: 0.6406, Validation Accuracy: 0.8000
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 14/20, Train Loss: 0.3765, Train Accuracy: 0.9741
# Validation Loss: 0.6571, Validation Accuracy: 0.8109
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.86it/s]
# Epoch 15/20, Train Loss: 0.3780, Train Accuracy: 0.9736
# Validation Loss: 0.6547, Validation Accuracy: 0.8073
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 16/20, Train Loss: 0.3746, Train Accuracy: 0.9722
# Validation Loss: 0.6552, Validation Accuracy: 0.8182
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 17/20, Train Loss: 0.3648, Train Accuracy: 0.9777
# Validation Loss: 0.6431, Validation Accuracy: 0.8145
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.85it/s]
# Epoch 18/20, Train Loss: 0.3684, Train Accuracy: 0.9777
# Validation Loss: 0.6203, Validation Accuracy: 0.8255
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.84it/s]
# Epoch 19/20, Train Loss: 0.3566, Train Accuracy: 0.9850
# Validation Loss: 0.6189, Validation Accuracy: 0.8145
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.83it/s]
# Epoch 20/20, Train Loss: 0.3596, Train Accuracy: 0.9813
# Validation Loss: 0.6361, Validation Accuracy: 0.8255
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.83      0.80      0.82       106
#       Psorasis       0.80      0.89      0.84       107
# Tinea Ringworm       0.91      0.80      0.85        64
#
#       accuracy                           0.83       277
#      macro avg       0.85      0.83      0.84       277
#   weighted avg       0.84      0.83      0.83       277
#
# Confusion Matrix:

# %%
#Modified InceptionV3

# %%
import torch.nn as nn
from torchvision import models

class Modified_InceptionV3(nn.Module):
    def __init__(self, num_classes):
        super(Modified_InceptionV3, self).__init__()
        self.base_model = models.inception_v3(pretrained=True, aux_logits=True)

        self.base_model.fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

        self.base_model.AuxLogits.fc = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        return self.base_model(x)

# %%
model = Modified_InceptionV3(num_classes=3)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(DEVICE) 
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20

MODEL_NAME = 'inception_v3'  # one of: resnet50, efficientnet_b0, inception_v3, convnext_tiny, vit_b_16, swin_tiny


def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)

# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((299,299)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((299,299)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)


# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)


# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            if isinstance(outputs, tuple):
                outputs = outputs[0]

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_inception_v3.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:05<00:00,  1.82s/it]
# Epoch 1/20, Train Loss: 0.9552, Train Accuracy: 0.5514
# Validation Loss: 0.8264, Validation Accuracy: 0.6509
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:58<00:00,  1.71s/it]
# Epoch 2/20, Train Loss: 0.5847, Train Accuracy: 0.7753
# Validation Loss: 0.6554, Validation Accuracy: 0.7673
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:56<00:00,  1.69s/it]
# Epoch 3/20, Train Loss: 0.3690, Train Accuracy: 0.8735
# Validation Loss: 0.5944, Validation Accuracy: 0.8109
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:57<00:00,  1.70s/it]
# Epoch 4/20, Train Loss: 0.2704, Train Accuracy: 0.9026
# Validation Loss: 0.5645, Validation Accuracy: 0.8182
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:55<00:00,  1.67s/it]
# Epoch 5/20, Train Loss: 0.2065, Train Accuracy: 0.9336
# Validation Loss: 0.6485, Validation Accuracy: 0.7927
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 6/20, Train Loss: 0.1981, Train Accuracy: 0.9240
# Validation Loss: 0.7950, Validation Accuracy: 0.7673
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.65s/it]
# Epoch 7/20, Train Loss: 0.1484, Train Accuracy: 0.9518
# Validation Loss: 0.6604, Validation Accuracy: 0.7782
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:53<00:00,  1.65s/it]
# Epoch 8/20, Train Loss: 0.1318, Train Accuracy: 0.9609
# Validation Loss: 0.6621, Validation Accuracy: 0.7891
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 9/20, Train Loss: 0.0871, Train Accuracy: 0.9700
# Validation Loss: 0.6746, Validation Accuracy: 0.8036
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 10/20, Train Loss: 0.1252, Train Accuracy: 0.9536
# Validation Loss: 0.7932, Validation Accuracy: 0.7927
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 11/20, Train Loss: 0.0809, Train Accuracy: 0.9736
# Validation Loss: 0.7729, Validation Accuracy: 0.8073
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:53<00:00,  1.65s/it]
# Epoch 12/20, Train Loss: 0.0910, Train Accuracy: 0.9754
# Validation Loss: 0.8855, Validation Accuracy: 0.7782
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 13/20, Train Loss: 0.0739, Train Accuracy: 0.9718
# Validation Loss: 0.8761, Validation Accuracy: 0.7855
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.65s/it]
# Epoch 14/20, Train Loss: 0.0741, Train Accuracy: 0.9750
# Validation Loss: 0.7994, Validation Accuracy: 0.8255
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.65s/it]
# Epoch 15/20, Train Loss: 0.0899, Train Accuracy: 0.9709
# Validation Loss: 0.8094, Validation Accuracy: 0.8182
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.65s/it]
# Epoch 16/20, Train Loss: 0.0552, Train Accuracy: 0.9813
# Validation Loss: 0.7052, Validation Accuracy: 0.8327
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 17/20, Train Loss: 0.0595, Train Accuracy: 0.9777
# Validation Loss: 0.8591, Validation Accuracy: 0.7927
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:54<00:00,  1.66s/it]
# Epoch 18/20, Train Loss: 0.0841, Train Accuracy: 0.9713
# Validation Loss: 0.6756, Validation Accuracy: 0.8036
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:53<00:00,  1.65s/it]
# Epoch 19/20, Train Loss: 0.0577, Train Accuracy: 0.9813
# Validation Loss: 0.7772, Validation Accuracy: 0.8182
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [01:53<00:00,  1.65s/it]
# Epoch 20/20, Train Loss: 0.0496, Train Accuracy: 0.9832
# Validation Loss: 0.8985, Validation Accuracy: 0.8036
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.77      0.76      0.77       106
#      Psoriasis       0.78      0.85      0.81       107
# Tinea_Ringworm       0.85      0.73      0.79        64
#
#       accuracy                           0.79       277
#      macro avg       0.80      0.78      0.79       277
#   weighted avg       0.79      0.79      0.79       277
#
# Confusion Matrix:

# %%
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Conv2d(channel, channel // reduction, 1),
            nn.ReLU(inplace=True),
            nn.Conv2d(channel // reduction, channel, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        scale = self.excitation(self.squeeze(x))
        return x * scale

class Modified1_InceptionV3(nn.Module):
    def __init__(self, num_classes):
        super(Modified1_InceptionV3, self).__init__()
        self.base_model = models.inception_v3(pretrained=True, aux_logits=True)

        # Insert SE block after Mixed_5b
        self.base_model.Mixed_5b = nn.Sequential(
            self.base_model.Mixed_5b,
            SEBlock(256)
        )

        # Replace FC layers
        self.base_model.fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

        self.base_model.AuxLogits.fc = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        return self.base_model(x)

# %%
model = Modified1_InceptionV3(num_classes=3)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(DEVICE) 
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
NUM_EPOCHS = 20



def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)

# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((299, 299)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)


# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)


# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    # Lists to store the loss and accuracy values per epoch
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        # Training loop
        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            if isinstance(outputs, tuple):
                outputs = outputs[0]

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track accuracy
            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        # Calculate average training loss and accuracy for the epoch
        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds

        # Append values for the current epoch
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        # Validation loop
        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                # Track accuracy
                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        # Calculate average validation loss and accuracy for the epoch
        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds

        # Append values for the current epoch
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        # Save the best model
        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    # Load the best model weights
    model.load_state_dict(best_model_wts)

    # Return model and the lists of losses and accuracies
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, NUM_EPOCHS
)

# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    # Plot Training and Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

# ------------------- Plot Loss and Accuracy ------------------- #
plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified1_inception_v3.pth')
evaluate_model(trained_model, test_loader)
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:30<00:00,  2.18s/it]
# Epoch 1/20, Train Loss: 0.9494, Train Accuracy: 0.5510
# Validation Loss: 0.7963, Validation Accuracy: 0.6473
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:29<00:00,  2.17s/it]
# Epoch 2/20, Train Loss: 0.5541, Train Accuracy: 0.7771
# Validation Loss: 0.6517, Validation Accuracy: 0.7564
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:29<00:00,  2.17s/it]
# Epoch 3/20, Train Loss: 0.3579, Train Accuracy: 0.8822
# Validation Loss: 0.6690, Validation Accuracy: 0.7636
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:29<00:00,  2.17s/it]
# Epoch 4/20, Train Loss: 0.2379, Train Accuracy: 0.9190
# Validation Loss: 0.7174, Validation Accuracy: 0.7564
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:29<00:00,  2.17s/it]
# Epoch 5/20, Train Loss: 0.2118, Train Accuracy: 0.9231
# Validation Loss: 0.7909, Validation Accuracy: 0.7745
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:29<00:00,  2.17s/it]
# Epoch 6/20, Train Loss: 0.1866, Train Accuracy: 0.9354
# Validation Loss: 0.6893, Validation Accuracy: 0.7782
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:30<00:00,  2.18s/it]
# Epoch 7/20, Train Loss: 0.1338, Train Accuracy: 0.9486
# Validation Loss: 0.6501, Validation Accuracy: 0.8218
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:30<00:00,  2.18s/it]
# Epoch 8/20, Train Loss: 0.1292, Train Accuracy: 0.9609
# Validation Loss: 0.7686, Validation Accuracy: 0.7745
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [02:32<00:00,  2.20s/it]
# Epoch 9/20, Train Loss: 0.0999, Train Accuracy: 0.9645
# Validation Loss: 0.7403, Validation Accuracy: 0.8109
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:33<00:00,  2.22s/it]
# Epoch 10/20, Train Loss: 0.1205, Train Accuracy: 0.9591
# Validation Loss: 0.7115, Validation Accuracy: 0.8000
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:32<00:00,  2.21s/it]
# Epoch 11/20, Train Loss: 0.0958, Train Accuracy: 0.9659
# Validation Loss: 0.6527, Validation Accuracy: 0.8182
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:36<00:00,  2.26s/it]
# Epoch 12/20, Train Loss: 0.0945, Train Accuracy: 0.9691
# Validation Loss: 0.6865, Validation Accuracy: 0.8182
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:36<00:00,  2.27s/it]
# Epoch 13/20, Train Loss: 0.0816, Train Accuracy: 0.9727
# Validation Loss: 0.6903, Validation Accuracy: 0.8218
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [03:40<00:00,  3.20s/it]
# Epoch 14/20, Train Loss: 0.0585, Train Accuracy: 0.9800
# Validation Loss: 0.7526, Validation Accuracy: 0.8073
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [04:25<00:00,  3.84s/it]
# Epoch 15/20, Train Loss: 0.0926, Train Accuracy: 0.9691
# Validation Loss: 0.5905, Validation Accuracy: 0.8327
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:44<00:00,  2.39s/it]
# Epoch 16/20, Train Loss: 0.0633, Train Accuracy: 0.9777
# Validation Loss: 0.6460, Validation Accuracy: 0.8000
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:48<00:00,  2.44s/it]
# Epoch 17/20, Train Loss: 0.0613, Train Accuracy: 0.9754
# Validation Loss: 0.6974, Validation Accuracy: 0.8073
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:44<00:00,  2.39s/it]
# Epoch 18/20, Train Loss: 0.0650, Train Accuracy: 0.9795
# Validation Loss: 0.7584, Validation Accuracy: 0.7964
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:47<00:00,  2.43s/it]
# Epoch 19/20, Train Loss: 0.0557, Train Accuracy: 0.9841
# Validation Loss: 0.8249, Validation Accuracy: 0.8255
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [02:48<00:00,  2.44s/it]
# Epoch 20/20, Train Loss: 0.0458, Train Accuracy: 0.9832
# Validation Loss: 0.8024, Validation Accuracy: 0.8000
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.72      0.76      0.74       106
#      Psoriasis       0.77      0.72      0.74       107
# Tinea_Ringworm       0.72      0.73      0.73        64
#
#       accuracy                           0.74       277
#      macro avg       0.74      0.74      0.74       277
#   weighted avg       0.74      0.74      0.74       277
#
# Confusion Matrix:

# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import datasets, transforms, models
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import label_binarize
from torchvision.models import resnet50
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights, vit_b_16, ViT_B_16_Weights
import timm
from transformers import ViTForImageClassification, ViTConfig
from matplotlib import font_manager as fm

# Directory configuration
MODEL_DIR = "/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models"
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'
test_classes = ['Eczema', 'Psoriasis', 'Tinea_Ringworm']

# Configure font
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"
fm.fontManager.addfont(font_path)
liberation_font = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = liberation_font.get_name()

# Define transformation for test data
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621]),
])

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load datasets
test_dataset = datasets.ImageFolder(os.path.join(DATA_DIR, 'test'), transform=transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=32, shuffle=False)

# Model definitions (keeping all your model class definitions)
class ModifiedResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(ModifiedResNet50, self).__init__()
        base_model = models.resnet50(pretrained=True)
        
        # Remove the original FC layer
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])  # Exclude avgpool & fc

        self.pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP
        self.classifier = nn.Sequential(
            nn.Flatten(),                           # Flatten after GAP
            nn.Linear(2048, 512),                   # FC layer
            nn.BatchNorm1d(512),                    # BatchNorm
            nn.LeakyReLU(0.1, inplace=True),        # LeakyReLU
            nn.Dropout(0.4),
            nn.Linear(512, num_classes)             # Final classification layer
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

class Modified1ResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(Modified1ResNet50, self).__init__()
        base_model = models.resnet50(pretrained=True)
        
        # Remove the original FC layer
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])  # Exclude avgpool & fc

        self.pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(2048, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.4),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.LeakyReLU(0.1),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)  
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

class Modified2ResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(Modified2ResNet50, self).__init__()
        base_model = models.resnet50(pretrained=True)
        
        # Remove the original FC layer
        self.feature_extractor = nn.Sequential(*list(base_model.children())[:-2])  # Exclude avgpool & fc

        self.pool = nn.AdaptiveAvgPool2d((1, 1))  # GAP
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(2048, 512),
            nn.BatchNorm1d(512),
            nn.SiLU(),                  # Replaces LeakyReLU
            nn.Dropout(0.4),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(),                  # Replaces LeakyReLU
            nn.Dropout(0.3),
            nn.Linear(128, num_classes) 
        )

    def forward(self, x):
        x = self.feature_extractor(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate=32, bn_size=4, drop_rate=0.2):
        super(DenseLayer, self).__init__()
        inter_channels = bn_size * growth_rate
        self.net = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, inter_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(inter_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(inter_channels, growth_rate, kernel_size=3, stride=1, padding=1, bias=False),
        )
        self.drop_rate = drop_rate

    def forward(self, x):
        new_features = self.net(x)
        if self.drop_rate > 0:
            new_features = nn.functional.dropout(new_features, p=self.drop_rate, training=self.training)
        return torch.cat([x, new_features], 1)

class DenseBlock(nn.Module):
    def __init__(self, num_layers, in_channels, growth_rate=32):
        super(DenseBlock, self).__init__()
        layers = []
        for i in range(num_layers):
            layers.append(DenseLayer(in_channels + i * growth_rate, growth_rate))
        self.block = nn.Sequential(*layers)

    def forward(self, x):
        return self.block(x)

class TransitionLayer(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(TransitionLayer, self).__init__()
        self.transition = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, out_channels, kernel_size=1, bias=False),
            nn.AvgPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.transition(x)

class Modified3ResNet50(nn.Module):
    def __init__(self, num_classes=3):
        super(Modified3ResNet50, self).__init__()
        base_model = resnet50(weights=None)  # or weights='IMAGENET1K_V1' if using pretrained

        # Keep all layers up to layer3
        self.backbone = nn.Sequential(
            base_model.conv1,
            base_model.bn1,
            base_model.relu,
            base_model.maxpool,
            base_model.layer1,
            base_model.layer2,
            base_model.layer3,
        )

        # Replace layer4 with DenseBlock
        self.dense_block = nn.Sequential(
            DenseBlock(num_layers=4, in_channels=1024, growth_rate=32),
            TransitionLayer(1024 + 4 * 32, 1024)
        )

        # Global pooling
        self.pool = nn.AdaptiveAvgPool2d((1, 1))

        # Custom classifier head
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(1024, 512),
            nn.BatchNorm1d(512),
            nn.SiLU(),
            nn.Dropout(0.4),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(),
            nn.Dropout(0.3),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        x = self.backbone(x)
        x = self.dense_block(x)
        x = self.pool(x)
        x = self.classifier(x)
        return x

class ModifiedEfficientNetB0(nn.Module):
    def __init__(self, num_classes=3, freeze_blocks=5):
        super(ModifiedEfficientNetB0, self).__init__()
        self.base_model = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)

        # Optionally freeze first N feature blocks
        for i, param in enumerate(self.base_model.features):
            if i < freeze_blocks:
                for p in param.parameters():
                    p.requires_grad = False

        in_features = self.base_model.classifier[1].in_features

        # Replace classifier
        self.base_model.classifier = nn.Sequential(
            nn.Dropout(p=0.4, inplace=True),
            nn.Linear(in_features, 512),
            nn.BatchNorm1d(512),
            nn.SiLU(inplace=True),
            nn.Dropout(p=0.3, inplace=True),
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.SiLU(inplace=True),
            nn.Dropout(p=0.2, inplace=True),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        return self.base_model(x)

class Modified_InceptionV3(nn.Module):
    def __init__(self, num_classes=3):
        super(Modified_InceptionV3, self).__init__()
        self.base_model = models.inception_v3(pretrained=True, aux_logits=True)

        self.base_model.fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

        self.base_model.AuxLogits.fc = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        return self.base_model(x)

class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.squeeze = nn.AdaptiveAvgPool2d(1)
        self.excitation = nn.Sequential(
            nn.Conv2d(channel, channel // reduction, 1),
            nn.ReLU(inplace=True),
            nn.Conv2d(channel // reduction, channel, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        scale = self.excitation(self.squeeze(x))
        return x * scale

class Modified1_InceptionV3(nn.Module):
    def __init__(self, num_classes=3):
        super(Modified1_InceptionV3, self).__init__()
        self.base_model = models.inception_v3(pretrained=True, aux_logits=True)

        # Insert SE block after Mixed_5b
        self.base_model.Mixed_5b = nn.Sequential(
            self.base_model.Mixed_5b,
            SEBlock(256)
        )

        # Replace FC layers
        self.base_model.fc = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

        self.base_model.AuxLogits.fc = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        if self.training:
            main_output, aux_output = self.base_model(x)
            return main_output, aux_output
        else:
            return self.base_model(x)

# Initialize ViT model with custom head
def initialize_vit_model(num_classes=3):
    model = vit_b_16(weights=ViT_B_16_Weights.IMAGENET1K_V1)
    # Replace the head with our own classifier for 3 classes
    model.heads = nn.Sequential(
        nn.Linear(model.hidden_dim, 512),
        nn.LayerNorm(512),
        nn.GELU(),
        nn.Dropout(0.1),
        nn.Linear(512, num_classes)
    )
    return model

# Define a proper model class mapping - with additional models
model_class_mapping = {
    'modified_resnet50.pth': ModifiedResNet50,
    'modified1_resnet50.pth': Modified1ResNet50,
    'modified2_resnet50.pth': Modified2ResNet50,
    'modified3_resnet50.pth': Modified3ResNet50,
    'modified_inception_v3.pth': Modified_InceptionV3,
    'modified1_inception_v3.pth': Modified1_InceptionV3,
    'modified_efficientnetb0.pth': ModifiedEfficientNetB0,
    'resnet50.pth': 'resnet50',
    'inception_v3.pth': 'inception_v3',
    'efficientnet_b0.pth': 'efficientnet_b0',
    'vit_b_16.pth': 'vit_b_16'
}

# Function to load a model
def load_model(model_path, model_name, num_classes=3):
    print(f"Loading model: {model_name} from {model_path}")
    model_name_lower = model_name.lower()
    
    # Check if model exists in mapping
    if model_name_lower not in model_class_mapping:
        raise ValueError(f"Model '{model_name}' not recognized")
        
    # Get the model class or identifier
    model_class_or_name = model_class_mapping[model_name_lower]
    
    # Initialize model based on class or identifier
    if model_class_or_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
    elif model_class_or_name == 'inception_v3':
        # Fix: Initialize with aux_logits=True for compatibility with the saved weights
        model = models.inception_v3(pretrained=True, aux_logits=True)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        # Modify AuxLogits classifier as well
        model.AuxLogits.fc = nn.Linear(model.AuxLogits.fc.in_features, num_classes)
    elif model_class_or_name == 'efficientnet_b0':
        # Use timm implementation for EfficientNet which may be more compatible with your saved weights
        try:
            model = timm.create_model('efficientnet_b0', pretrained=True, num_classes=num_classes)
        except:
            # Fallback to torchvision implementation with strict=False for loading weights
            print("Falling back to torchvision implementation")
            model = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
            model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    elif model_class_or_name == 'vit_b_16':
        try:
            # Use the Hugging Face implementation instead of torchvision
            model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", 
                                                             num_labels=num_classes)
            state_dict = torch.load(model_path, map_location=device)
            model.load_state_dict(state_dict)
            print(f"Successfully loaded weights for {model_name}")
        except Exception as e:
            print(f"Error loading weights for {model_name}: {e}")
            print(f"Using pretrained model instead for {model_name}")
            # Just use the pretrained model
            model = ViTForImageClassification.from_pretrained("google/vit-base-patch16-224-in21k", 
                                                             num_labels=num_classes)
    else:
        # For custom models that are actual classes
        model = model_class_or_name(num_classes=num_classes)
    
    # Load model weights
    try:
        state_dict = torch.load(model_path, map_location=device)
        
        # For efficientnet models, try loading with strict=False to handle key mismatches
        if model_name_lower == 'efficientnet_b0.pth':
            model.load_state_dict(state_dict, strict=False)
            print(f"Loaded {model_name} weights with strict=False to handle architecture differences")
        else:
            # For InceptionV3, also use strict=False to handle any aux_logits differences
            if model_name_lower == 'inception_v3.pth':
                model.load_state_dict(state_dict, strict=False)
                print(f"Loaded {model_name} weights with strict=False to handle aux_logits differences")
            else:
                model.load_state_dict(state_dict)
            
        print(f"Successfully loaded weights for {model_name}")
    except Exception as e:
        print(f"Error loading weights for {model_name}: {e}")
        if model_name_lower in ['efficientnet_b0.pth', 'inception_v3.pth', 'vit_b_16.pth']:
            print(f"Using pretrained model instead for {model_name}")
            # Continue with the pretrained model
        else:
            raise
    
    model = model.to(device)
    model.eval()
    return model

# Handle InceptionV3 input size requirements
def process_batch_with_model(model, inputs, labels, model_name_lower):
    # InceptionV3 expects 299x299 inputs
    if 'inception_v3' in model_name_lower:
        if inputs.shape[2] != 299:
            resized_inputs = torch.nn.functional.interpolate(inputs, size=(299, 299), mode='bilinear', align_corners=False)
            outputs = model(resized_inputs)
        else:
            outputs = model(inputs)
    else:
        outputs = model(inputs)

    # For HuggingFace ViT models, extract logits
    if isinstance(outputs, dict) or hasattr(outputs, 'logits'):
        outputs = outputs.logits

    # Handle InceptionV3 outputs (tuple)
    if isinstance(outputs, tuple):
        outputs = outputs[0]

    _, preds = torch.max(outputs, 1)
    probabilities = torch.softmax(outputs, dim=1)

    return preds, probabilities


# Calculate sensitivity and specificity
def calculate_sensitivity_specificity(cm):
    """Calculate sensitivity and specificity for each class from confusion matrix"""
    n_classes = cm.shape[0]
    sensitivity = np.zeros(n_classes)
    specificity = np.zeros(n_classes)
    
    for i in range(n_classes):
        # True Positive for class i
        tp = cm[i, i]
        # False Negative for class i
        fn = np.sum(cm[i, :]) - tp
        # False Positive for class i
        fp = np.sum(cm[:, i]) - tp
        # True Negative for class i
        tn = np.sum(cm) - tp - fn - fp
        
        # Calculate metrics
        sensitivity[i] = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity[i] = tn / (tn + fp) if (tn + fp) > 0 else 0
    
    # Also calculate macro-average
    macro_sensitivity = np.mean(sensitivity)
    macro_specificity = np.mean(specificity)
    
    return sensitivity, specificity, macro_sensitivity, macro_specificity

# Functions for evaluation metrics
def plot_confusion_matrix(cm, labels, model_name):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)
    plt.title(f"Confusion Matrix - {model_name}", fontproperties=liberation_font)
    plt.xlabel('Predicted', fontproperties=liberation_font)
    plt.ylabel('Actual', fontproperties=liberation_font)
    plt.savefig(os.path.join(MODEL_DIR, f"{model_name}_confusion_matrix.png"))
    plt.close()

def plot_roc_curve_multiclass(y_test, y_score, class_names, model_name):
    """
    Plot ROC curve for multiclass classification.
    
    Parameters:
    y_test (array): One-hot encoded true class labels
    y_score (array): Predicted probabilities for each class
    class_names (list): List of class names
    model_name (str): Name of the model for the plot title
    """
    n_classes = len(class_names)
    
    # Plot ROC curve for each class
    plt.figure(figsize=(10, 8))
    
    # Compute micro-average ROC curve and ROC area
    fpr = {}
    tpr = {}
    roc_auc = {}
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc[i] = roc_auc_score(y_test[:, i], y_score[:, i])
        plt.plot(fpr[i], tpr[i], lw=2, 
                 label=f'{class_names[i]} (AUC = {roc_auc[i]:.2f})')
    
    # Plot the diagonal
    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate', fontproperties=liberation_font)
    plt.ylabel('True Positive Rate', fontproperties=liberation_font)
    plt.title(f'ROC Curve (Multiclass) - {model_name}', fontproperties=liberation_font)
    plt.legend(loc="lower right")
    plt.savefig(os.path.join(MODEL_DIR, f"{model_name}_roc_curve_multiclass.png"))
    plt.close()
    
    return roc_auc

# Main evaluation loop
def evaluate_models():
    results = []
    
    # List model files in directory
    model_files = [f for f in os.listdir(MODEL_DIR) if f.lower().endswith('.pth') and f.lower() in model_class_mapping]
    
    print(f"Found {len(model_files)} models to evaluate: {model_files}")
    
    for model_filename in model_files:
        model_path = os.path.join(MODEL_DIR, model_filename)
        model_name_lower = model_filename.lower()
        
        try:
            print(f"Evaluating model: {model_filename}")
            model = load_model(model_path, model_filename)
            
            all_preds = []
            all_labels = []
            all_probabilities = []
            
            with torch.no_grad():
                for inputs, labels in test_loader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)
                    
                    # Process batch using helper function that handles model-specific requirements
                    preds, probabilities = process_batch_with_model(model, inputs, labels, model_name_lower)
                    
                    all_preds.append(preds.cpu().numpy())
                    all_labels.append(labels.cpu().numpy())
                    all_probabilities.append(probabilities.cpu().numpy())
            
            # Flatten lists
            all_preds = np.concatenate(all_preds)
            all_labels = np.concatenate(all_labels)
            all_probabilities = np.concatenate(all_probabilities)
            
            # Compute classification metrics
            cm = confusion_matrix(all_labels, all_preds)
            cr = classification_report(all_labels, all_preds, output_dict=True)
            accuracy = accuracy_score(all_labels, all_preds)
            precision, recall, fscore, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
            
            # Calculate sensitivity and specificity
            sensitivity_per_class, specificity_per_class, macro_sensitivity, macro_specificity = calculate_sensitivity_specificity(cm)
            
            # Binarize labels for ROC-AUC (one-hot encoding)
            all_labels_bin = label_binarize(all_labels, classes=range(len(test_classes)))
            
            # Plot confusion matrix
            plot_confusion_matrix(cm, test_classes, model_filename)
            
            # Plot multiclass ROC curve and get AUC scores per class
            class_auc_dict = plot_roc_curve_multiclass(all_labels_bin, all_probabilities, test_classes, model_filename)
            
            # Calculate average AUC across all classes (macro average)
            macro_auc = np.mean(list(class_auc_dict.values()))
            
            # Store detailed results for each class
            class_results = {}
            for i, class_name in enumerate(test_classes):
                class_results[f"{class_name}_AUC"] = class_auc_dict[i]
                class_results[f"{class_name}_Precision"] = cr[str(i)]['precision']
                class_results[f"{class_name}_Recall"] = cr[str(i)]['recall'] 
                class_results[f"{class_name}_F1"] = cr[str(i)]['f1-score']
                class_results[f"{class_name}_Sensitivity"] = sensitivity_per_class[i]
                class_results[f"{class_name}_Specificity"] = specificity_per_class[i]
            
            # Store results
            result_dict = {
                'Model': model_filename,
                'Accuracy': accuracy,
                'Macro_Precision': precision,
                'Macro_Recall': recall,
                'Macro_F1': fscore,
                'Macro_AUC': macro_auc,
                'Macro_Sensitivity': macro_sensitivity,
                'Macro_Specificity': macro_specificity
            }
            
            # Add per-class metrics
            result_dict.update(class_results)
            results.append(result_dict)
            
            print(f"Completed evaluation for {model_filename}")
            print(f"  Accuracy: {accuracy:.4f}, Macro AUC: {macro_auc:.4f}")
            print(f"  Sensitivity: {macro_sensitivity:.4f}, Specificity: {macro_specificity:.4f}")
            
        except Exception as e:
            print(f"Error evaluating model {model_filename}: {e}")
            import traceback
            traceback.print_exc()  # Print full traceback for better debugging
            continue
    
    # Save results to CSV
    if results:
        results_df = pd.DataFrame(results)
        results_df.to_csv(os.path.join(MODEL_DIR, 'model_evaluation_results.csv'), index=False)
        
        # Also save a more readable summary with just the main metrics
        summary_cols = ['Model', 'Accuracy', 'Macro_Precision', 'Macro_Recall', 'Macro_F1', 'Macro_AUC', 'Macro_Sensitivity', 'Macro_Specificity']
        summary_results = results_df[summary_cols]
        summary_results = summary_results.sort_values('Accuracy', ascending=False)
        summary_results.to_csv(os.path.join(MODEL_DIR, 'model_evaluation_summary.csv'), index=False)
        
        print("Evaluation completed and results saved.")
    else:
        print("No results were produced. Check errors above.")

# Run the evaluation
if __name__ == "__main__":
    evaluate_models()
# Out:
# Found 11 models to evaluate: ['efficientnet_b0.pth', 'inception_v3.pth', 'Modified1_inception_v3.pth', 'Modified1_resnet50.pth', 'Modified2_resnet50.pth', 'Modified3_resnet50.pth', 'Modified_efficientnetb0.pth', 'Modified_inception_v3.pth', 'Modified_resnet50.pth', 'resnet50.pth', 'vit_b_16.pth']
# Evaluating model: efficientnet_b0.pth
# Loading model: efficientnet_b0.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/efficientnet_b0.pth
# Loaded efficientnet_b0.pth weights with strict=False to handle architecture differences
# Successfully loaded weights for efficientnet_b0.pth
# Completed evaluation for efficientnet_b0.pth
#   Accuracy: 0.7870, Macro AUC: 0.9140
#   Sensitivity: 0.7925, Specificity: 0.8894
# Evaluating model: inception_v3.pth
# Loading model: inception_v3.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/inception_v3.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loaded inception_v3.pth weights with strict=False to handle aux_logits differences
# Successfully loaded weights for inception_v3.pth
# Completed evaluation for inception_v3.pth
#   Accuracy: 0.7473, Macro AUC: 0.8848
#   Sensitivity: 0.7370, Specificity: 0.8689
# Evaluating model: Modified1_inception_v3.pth
# Loading model: Modified1_inception_v3.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified1_inception_v3.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Successfully loaded weights for Modified1_inception_v3.pth
# Completed evaluation for Modified1_inception_v3.pth
#   Accuracy: 0.7509, Macro AUC: 0.9011
#   Sensitivity: 0.7506, Specificity: 0.8690
# Evaluating model: Modified1_resnet50.pth
# Loading model: Modified1_resnet50.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified1_resnet50.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Successfully loaded weights for Modified1_resnet50.pth
# Completed evaluation for Modified1_resnet50.pth
#   Accuracy: 0.7617, Macro AUC: 0.9139
#   Sensitivity: 0.7517, Specificity: 0.8740
# Evaluating model: Modified2_resnet50.pth
# Loading model: Modified2_resnet50.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified2_resnet50.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Successfully loaded weights for Modified2_resnet50.pth
# Completed evaluation for Modified2_resnet50.pth
#   Accuracy: 0.8267, Macro AUC: 0.9394
#   Sensitivity: 0.8246, Specificity: 0.9092
# Evaluating model: Modified3_resnet50.pth
# Loading model: Modified3_resnet50.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified3_resnet50.pth
# Successfully loaded weights for Modified3_resnet50.pth
# Completed evaluation for Modified3_resnet50.pth
#   Accuracy: 0.5271, Macro AUC: 0.7351
#   Sensitivity: 0.5277, Specificity: 0.7576
# Evaluating model: Modified_efficientnetb0.pth
# Loading model: Modified_efficientnetb0.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_efficientnetb0.pth
# Successfully loaded weights for Modified_efficientnetb0.pth
# Completed evaluation for Modified_efficientnetb0.pth
#   Accuracy: 0.8339, Macro AUC: 0.9366
#   Sensitivity: 0.8289, Specificity: 0.9120
# Evaluating model: Modified_inception_v3.pth
# Loading model: Modified_inception_v3.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_inception_v3.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Successfully loaded weights for Modified_inception_v3.pth
# Completed evaluation for Modified_inception_v3.pth
#   Accuracy: 0.7473, Macro AUC: 0.9119
#   Sensitivity: 0.7556, Specificity: 0.8677
# Evaluating model: Modified_resnet50.pth
# Loading model: Modified_resnet50.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_resnet50.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Successfully loaded weights for Modified_resnet50.pth
# Completed evaluation for Modified_resnet50.pth
#   Accuracy: 0.8051, Macro AUC: 0.9374
#   Sensitivity: 0.8121, Specificity: 0.9010
# Evaluating model: resnet50.pth
# Loading model: resnet50.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/resnet50.pth
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Successfully loaded weights for resnet50.pth
# Completed evaluation for resnet50.pth
#   Accuracy: 0.8014, Macro AUC: 0.9286
#   Sensitivity: 0.8049, Specificity: 0.8995
# Evaluating model: vit_b_16.pth
# Loading model: vit_b_16.pth from /mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/vit_b_16.pth
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Successfully loaded weights for vit_b_16.pth
# Successfully loaded weights for vit_b_16.pth
# Completed evaluation for vit_b_16.pth
#   Accuracy: 0.8339, Macro AUC: 0.9528
#   Sensitivity: 0.8287, Specificity: 0.9111
# Evaluation completed and results saved.

# %%
#Modified EfficientnetB0+ViT

# %%
import torch
import torch.nn as nn
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights
from torchvision.models.vision_transformer import vit_b_16, ViT_B_16_Weights  # or vit_l_16 for large

class EfficientNetWithViT(nn.Module):
    def __init__(self, num_classes=3, freeze_blocks=5, use_pretrained_vit=False):
        super(EfficientNetWithViT, self).__init__()

        # Load EfficientNetB0
        self.effnet = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
        for param in self.effnet.features[:freeze_blocks]:
            param.requires_grad = False

        # Remove original classifier
        self.feature_extractor = nn.Sequential(
            self.effnet.features,
            self.effnet.avgpool,  # output shape: (B, 1280, 1, 1)
            nn.Flatten(start_dim=1)  # shape: (B, 1280)
        )

        # Project 1280-d to sequence of tokens (e.g., 8 tokens of 160-d)
        self.project_to_tokens = nn.Linear(1280, 160 * 8)  # shape -> (B, 1280) → (B, 1280) → reshape (B, 8, 160)

        # Lightweight ViT (or pretrained)
        self.vit_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=160, nhead=4, dim_feedforward=256, dropout=0.1, activation="gelu"),
            num_layers=2
        )

        # Classifier after ViT
        self.classifier = nn.Sequential(
            nn.Linear(160 * 8, 256),
            nn.BatchNorm1d(256),
            nn.SiLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.feature_extractor(x)              # shape: (B, 1280)
        x = self.project_to_tokens(x)              # shape: (B, 1280) → (B, 1280)
        x = x.view(x.size(0), 8, 160)              # reshape to tokens: (B, 8, 160)

        x = self.vit_encoder(x)                    # output: (B, 8, 160)
        x = x.flatten(start_dim=1)                 # flatten: (B, 1280)

        x = self.classifier(x)                     # final output: (B, num_classes)
        return x
# Out:
# /home/pragya/.local/lib/python3.10/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %%
import torch
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, WeightedRandomSampler
from transformers import ViTForImageClassification, ViTFeatureExtractor
import timm
import os
from collections import Counter
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import time
import random
from matplotlib import font_manager as fm
font_path = "/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf"

# ✅ Force-add the font
fm.fontManager.addfont(font_path)

# ✅ Create a font properties object
liberation_font = fm.FontProperties(fname=font_path)
# ✅ Apply the font globally to all plots
plt.rcParams['font.family'] = liberation_font.get_name()

# ------------------- Config ------------------- #
DATA_DIR = '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset'  # should have train/val/test folders
BATCH_SIZE = 32
NUM_CLASSES = 3
model = EfficientNetWithViT(num_classes=3)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(DEVICE)
NUM_EPOCHS = 20


def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(42)
# ------------------- Transforms ------------------- #
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])
val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.5285, 0.3926, 0.3573], [0.2076, 0.1692, 0.1621])
])


# ------------------- Dataset ------------------- #
train_dataset = ImageFolder(os.path.join(DATA_DIR, 'train'), transform=train_transform)
val_dataset = ImageFolder(os.path.join(DATA_DIR, 'val'), transform=val_test_transform)
test_dataset = ImageFolder(os.path.join(DATA_DIR, 'test'), transform=val_test_transform)

# ------------------- DataLoader ------------------- #
# Weighted sampling to handle class imbalance
class_counts = [count for _, count in Counter(train_dataset.targets).items()]
class_weights = 1. / np.array(class_counts, dtype=np.float32)
weights = class_weights[train_dataset.targets]

sampler = WeightedRandomSampler(weights, len(weights))

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)




# ------------------- Loss and Optimizer ------------------- #
criterion = torch.nn.CrossEntropyLoss(label_smoothing=0.1)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, verbose=True
)

# ------------------- Training Function with Loss and Accuracy Per Epoch ------------------- #
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, num_epochs):
    best_model_wts = model.state_dict()
    best_acc = 0.0

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        correct_preds = 0
        total_preds = 0

        for inputs, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs}'):
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            optimizer.zero_grad()

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            correct_preds += torch.sum(preds == labels).item()
            total_preds += labels.size(0)
            running_loss += loss.item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = correct_preds / total_preds
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_correct_preds = 0
        val_total_preds = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
                outputs = model(inputs)
                loss = criterion(outputs, labels)

                _, preds = torch.max(outputs, 1)
                val_correct_preds += torch.sum(preds == labels).item()
                val_total_preds += labels.size(0)
                val_loss += loss.item()

        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = val_correct_preds / val_total_preds
        val_losses.append(val_epoch_loss)
        val_accuracies.append(val_epoch_acc)

        scheduler.step(val_epoch_loss)

        print(f"Validation Loss: {val_epoch_loss:.4f}, Validation Accuracy: {val_epoch_acc:.4f}")

        if val_epoch_acc > best_acc:
            best_acc = val_epoch_acc
            best_model_wts = model.state_dict()

    model.load_state_dict(best_model_wts)
    return model, train_losses, val_losses, train_accuracies, val_accuracies

# ------------------- Training the Model ------------------- #
start_time = time.time()
trained_model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, scheduler, NUM_EPOCHS
)
end_time = time.time()
training_duration = end_time - start_time

print(f"\n✅ Total Training Time: {training_duration:.2f} seconds ({training_duration/60:.2f} minutes)")
# ------------------- Plotting Loss and Accuracy ------------------- #
def plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies):
    epochs = range(1, NUM_EPOCHS + 1)
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Train vs Validation Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, train_accuracies, label='Train Accuracy', color='blue')
    plt.plot(epochs, val_accuracies, label='Validation Accuracy', color='red')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Train vs Validation Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_loss_accuracy(train_losses, val_losses, train_accuracies, val_accuracies)

# ------------------- Evaluate on Test Set ------------------- #
def evaluate_model(model, test_loader):
    model.eval()
    test_preds = []
    test_labels = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            test_preds.extend(preds.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    print("Classification Report:")
    print(classification_report(test_labels, test_preds, target_names=test_loader.dataset.classes))

    print("Confusion Matrix:")
    cm = confusion_matrix(test_labels, test_preds)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_loader.dataset.classes, yticklabels=test_loader.dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# ------------------- Save and Evaluate ------------------- #
torch.save(model.state_dict(), '/mnt/c/Users/pragy/Downloads/Dataset/Original Images/Split_Dataset/Models/Modified_efficientnetb0ViT.pth')
evaluate_model(trained_model, test_loader)
# Out:
# 2025-05-22 19:24:51.335896: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-22 19:24:51.654740: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-22 19:24:51.768130: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-22 19:24:52.802181: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2025-05-22 19:24:52.802481: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:
# 2025-05-22 19:24:52.802490: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/pragya/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /home/pragya/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 1/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:27<00:00,  2.47it/s]
# Epoch 1/20, Train Loss: 0.9152, Train Accuracy: 0.6015
# Validation Loss: 0.8877, Validation Accuracy: 0.6400
# Epoch 2/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.73it/s]
# Epoch 2/20, Train Loss: 0.6946, Train Accuracy: 0.7780
# Validation Loss: 0.7813, Validation Accuracy: 0.7236
# Epoch 3/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.74it/s]
# Epoch 3/20, Train Loss: 0.5831, Train Accuracy: 0.8526
# Validation Loss: 0.7105, Validation Accuracy: 0.7600
# Epoch 4/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.74it/s]
# Epoch 4/20, Train Loss: 0.5011, Train Accuracy: 0.9013
# Validation Loss: 0.7160, Validation Accuracy: 0.7600
# Epoch 5/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.73it/s]
# Epoch 5/20, Train Loss: 0.4689, Train Accuracy: 0.9231
# Validation Loss: 0.6950, Validation Accuracy: 0.8073
# Epoch 6/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.78it/s]
# Epoch 6/20, Train Loss: 0.4420, Train Accuracy: 0.9372
# Validation Loss: 0.6840, Validation Accuracy: 0.7855
# Epoch 7/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.81it/s]
# Epoch 7/20, Train Loss: 0.4142, Train Accuracy: 0.9468
# Validation Loss: 0.6784, Validation Accuracy: 0.7891
# Epoch 8/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.81it/s]
# Epoch 8/20, Train Loss: 0.4029, Train Accuracy: 0.9559
# Validation Loss: 0.6644, Validation Accuracy: 0.8036
# Epoch 9/20: 100%|███████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.79it/s]
# Epoch 9/20, Train Loss: 0.3820, Train Accuracy: 0.9741
# Validation Loss: 0.6878, Validation Accuracy: 0.7782
# Epoch 10/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.83it/s]
# Epoch 10/20, Train Loss: 0.3795, Train Accuracy: 0.9750
# Validation Loss: 0.6619, Validation Accuracy: 0.8218
# Epoch 11/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:26<00:00,  2.63it/s]
# Epoch 11/20, Train Loss: 0.3713, Train Accuracy: 0.9777
# Validation Loss: 0.6479, Validation Accuracy: 0.8182
# Epoch 12/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.72it/s]
# Epoch 12/20, Train Loss: 0.3635, Train Accuracy: 0.9791
# Validation Loss: 0.6481, Validation Accuracy: 0.8218
# Epoch 13/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.73it/s]
# Epoch 13/20, Train Loss: 0.3587, Train Accuracy: 0.9832
# Validation Loss: 0.6560, Validation Accuracy: 0.8182
# Epoch 14/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:27<00:00,  2.52it/s]
# Epoch 14/20, Train Loss: 0.3496, Train Accuracy: 0.9859
# Validation Loss: 0.6475, Validation Accuracy: 0.8109
# Epoch 15/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:28<00:00,  2.41it/s]
# Epoch 15/20, Train Loss: 0.3483, Train Accuracy: 0.9877
# Validation Loss: 0.6335, Validation Accuracy: 0.8327
# Epoch 16/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:27<00:00,  2.50it/s]
# Epoch 16/20, Train Loss: 0.3431, Train Accuracy: 0.9873
# Validation Loss: 0.6110, Validation Accuracy: 0.8291
# Epoch 17/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:28<00:00,  2.39it/s]
# Epoch 17/20, Train Loss: 0.3482, Train Accuracy: 0.9882
# Validation Loss: 0.6211, Validation Accuracy: 0.8364
# Epoch 18/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:28<00:00,  2.41it/s]
# Epoch 18/20, Train Loss: 0.3432, Train Accuracy: 0.9909
# Validation Loss: 0.6145, Validation Accuracy: 0.8400
# Epoch 19/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:25<00:00,  2.71it/s]
# Epoch 19/20, Train Loss: 0.3376, Train Accuracy: 0.9900
# Validation Loss: 0.5960, Validation Accuracy: 0.8509
# Epoch 20/20: 100%|██████████████████████████████████████████████████████████████████████| 69/69 [00:24<00:00,  2.79it/s]
# Epoch 20/20, Train Loss: 0.3341, Train Accuracy: 0.9909
# Validation Loss: 0.6056, Validation Accuracy: 0.8473
#
# ✅ Total Training Time: 566.14 seconds (9.44 minutes)
# Classification Report:
#                 precision    recall  f1-score   support
#
#         Eczema       0.80      0.77      0.79       106
#      Psoriasis       0.79      0.82      0.80       107
# Tinea_Ringworm       0.78      0.77      0.77        64
#
#       accuracy                           0.79       277
#      macro avg       0.79      0.79      0.79       277
#   weighted avg       0.79      0.79      0.79       277
#
# Confusion Matrix:
